# %% [markdown]
# <a href="https://colab.research.google.com/github/custom-hyper/Trading-Report/blob/main/2023-05-12%20%E2%80%93Trading_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CoinGecko_id = "bitcoin" #@param {type:"string"}
yahoo_id = "TSLA" #@param {type:"string"}

# %% [markdown]
# Archive:

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
#@title
# !pip install statistics --quiet
# !pip install yfinance --quiet
# !pip install pytrends --quiet
# !pip install pycoingecko --quiet
# !pip install pandas --quiet
# !pip install Backtesting --quiet
# !pip install mplfinance --quiet
# !pip install configparser --quiet
# !pip install psycopg2-binary==2.8.6 --quiet
# !pip install tweepy==4.10.1 --quiet
# Out:
# Mounted at /content/drive
#   Preparing metadata (setup.py) ... done
#   Building wheel for statistics (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for Backtesting (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.7/384.7 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for psycopg2-binary (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 4.3 MB/s eta 0:00:00

# %%
#@title Import Project  Dependencies { display-mode: "code" }
import requests
import mplfinance as fplt
from datetime import datetime as dt
from datetime import timedelta
from datetime import date

import time
import json
import seaborn as sns
from google.colab import data_table
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import logging
import sys
from tqdm.notebook import tqdm
import os
import sqlite3 as sq
import psycopg2 as pg
import configparser
from sqlalchemy import create_engine
from pycoingecko import CoinGeckoAPI
import numpy as np
#from __future__ import division

# %% [markdown]
# Highlights

# %%
#@title Set up SQLite { display-mode: "code" }
#@title  Connect { display-mode: "code" }
path = '/content/drive/MyDrive/workspace/pipelines/db/' #@param {type: 'string'
database = "db.sqlite" #@param {type: 'string'
conn_SQLite = sq.connect(path+database)

# %% [markdown]
# # Big  Picture

# %%
#@title
#@title Google Trends
import seaborn as sns
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(10, 5))
# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()


pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
# <ipython-input-5-1b804749d541>:21: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "y1" (-> marker='1'). The keyword argument will take precedence.
#   plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y1" (-> color='y'). The keyword argument will take precedence.
#   plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "y2" (-> marker='2'). The keyword argument will take precedence.
#   plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y2" (-> color='y'). The keyword argument will take precedence.
#   plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "y3" (-> marker='3'). The keyword argument will take precedence.
#   plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y3" (-> color='y'). The keyword argument will take precedence.
#   plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title
#@title Crypto Fear & Greed Index

import requests

from datetime import datetime
import time
import json
from google.colab import data_table
import numpy as np
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt



#General Information table
response = requests.get("https://api.alternative.me/fng/?limit=0")
output = response.text
json_parsed = json.loads(output)

df = pd.json_normalize(json_parsed)


df1 = pd.concat([pd.json_normalize(x) for x in df['data'].values.tolist()])
timeseries = df1['timestamp']
df1['date'] = pd.to_datetime(df1['timestamp'], unit = 's')

df_fear_greed = pd.concat([df1['date'], df1['value']], axis=1)
df3 = pd.concat([df1['date'], df1['value_classification']])

# %%
#@title
#@title


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

plt.style.use("dark_background")
#sns.set_theme(style="darkgrid")

#Choose the date range
df_fear_greed = df_fear_greed[(df_fear_greed['date'] > '2016-04-01')]

df_fear_greed['value'] = df_fear_greed['value'].astype(int)
 
plt.figure(figsize=(20, 5))

sns.lineplot(data=df_fear_greed, linewidth=2.5, x="date", y="value", sort=False)
#sns.lineplot(df_fear_greed=df, linewidth=2.5, x="date", y="TotalCapMrktCurUSD")
plt.title('Crypto Fear & Greed Index Score')

plt.xticks(rotation=45)

plt.legend()


df_fear_greed.head(1)


import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

df_fear_greed['daily_ret'] = df_fear_greed['value'].pct_change(1)

ECDF = sns.displot(df_fear_greed, x="daily_ret", kind="ecdf")

Histogram = df_fear_greed['daily_ret'].hist(bins = 50)


plt.title('Daily Return %')

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Technical Analysis

# %%
#@title S&P 500
import yfinance as yf
import plotly.graph_objects as go


ticker='SPY'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['longName']


data = yf.download(tickers=ticker, period='200d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")

# %%
#@title  VIX
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='^VIX'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['Ticker']

data = yf.download(tickers=ticker, period='200d')
print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['Close'].hist(bins = 50,figsize = (7,5))
sns.displot(data, x="daily_ret", kind="ecdf")


plt.title('Daily Return %')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – ^VIX
#
# – Stock Market News for May 11, 2023
# – Stock Market News for May 10, 2023
# – Stock Market News for May 8, 2023
# – Stock Market News for May 5, 2023
# – Markets haven't started to 'correct aggressively yet': TCW CEO
# – Stock Market News for May 4, 2023
# – Debt Ceiling Debate Doesn't Mean 'Sell in May and Go Away'
# /usr/local/lib/python3.10/dist-packages/mplfinance/plotting.py:694: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   volumeAxes.set_ylim(vymin,vymax)
# Text(0.5, 1.0, 'Daily Return %')

# %%
#@title

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )


data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))
sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# /usr/local/lib/python3.10/dist-packages/mplfinance/plotting.py:694: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   volumeAxes.set_ylim(vymin,vymax)

# %%
#@title Bitcoin
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='BTC-USD'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['shortName']
#ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass
  
fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )
data['daily_ret'] = data['Close'].pct_change(1)

data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – BTC-USD

# %%
#@title Ethereum
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='ETH-USD'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['shortName']
#ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

  
fplt.plot(
            data,
            type='candle',
            style='mike',
            title =ticker,
            ylabel='Price ($)',
            volume=True,
            mav = (10,20,50,100,200),
            ylabel_lower='Volume',
            )

data['daily_ret'] = data['Close'].pct_change(1)

data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – ETH-USD
#
# – Perpetua Resources Announces First Quarter 2023 Highlights
# – India e-Waste Management Market Report 2023: Analysis of the Largest Producer of e-Waste after China and the United States
# – Gasket and Seal Materials Market size to grow at a CAGR of 5.84% from 2022 to 2027, Market is segmented by end-user, application, and geography - Technavio
# – Media, Public Invited to Meet Solvers in NASA Space Food Challenge
# – Equitable Bank releases ESG Performance Report and Public Accountability Statement
# – Meet Baby Dutton. The ‘Yellowstone’ Effect Extends to Boy Names
# – Why Dutch Bros Stock Sank This Week

# %%
#@title Correlation

import numpy as np 
import pandas as pd 
# Used to grab the stock prices, with yahoo 
import pandas_datareader as web 
from datetime import datetime 
# To visualize the results 
import matplotlib.pyplot as plt 
import seaborn

start = datetime(2022,9, 1)
symbols_list = [yahoo_id,'SPY', 'QQQ', 'ETH-USD', 'BTC-USD', 'TLT', 'DXY', 'GLD-USD']
#array to store prices
symbols=[]

#array to store prices
symbols=[]
for ticker in symbols_list:     
    
    r = yf.download(tickers=ticker, period='200d')
    # add a symbol column   
    r['Symbol'] = ticker    
    symbols.append(r)
# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
unknown= df[['Date', 'Close', 'Symbol']]
df.head()
df_pivot=df.pivot('Date','Symbol','Close')#.reset_index()
df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DXY: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-14-e64b41adb511>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Close')#.reset_index()

# %% [markdown]
# # Crypto

# %% [markdown]
# Trade Management

# %%
#@title Fundamentals

import requests
import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()

  
response = requests.get("https://api.coingecko.com/api/v3/coins/{}".format(CoinGecko_id))
output = response.text
json_parsed = json.loads(output)


x = json_parsed['market_data']['fully_diluted_valuation']

def fdv_none_val(x):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if x is None :
    fully_diluted_valuation = 0
  else :
    fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']
  
  return fully_diluted_valuation



def zero_div(x,y):
  """
  handling 0 division error
    
  """
  try:
      return x/y
  except ZeroDivisionError:
      return 0
links = 'Complete list: '+str(json_parsed['links'])
chat_url = 'Chat: '+str(json_parsed['links']['chat_url'])
CoinGecko_Link =  'CoinGecko: '+ "https://www.coingecko.com/en/coins/" + CoinGecko_id
Twitters = 'Twitter: '+str('https://twitter.com/')+str(json_parsed['links']['twitter_screen_name'])
homepage = 'Homepage: '+str(json_parsed['links']['homepage'])
subreddit_url =  'Reddit: ' +str(json_parsed['links']['subreddit_url'])
pd.set_option('display.width', 10)

print('')
print('WEB Links')
print('')
print(homepage)
print(Twitters)
print(subreddit_url)
print(chat_url)
print(CoinGecko_Link)

print(links)

print('')  
print('MARKET DATA')  
print('')  


market_cap = json_parsed['market_data']['market_cap']['usd']
circulating_supply = json_parsed['market_data']['circulating_supply']
# circulating_supply.astype(int) 
current_price = json_parsed['market_data']['current_price']['usd']
# current_price.astype(int) 
fdv_to_tvl_rati = json_parsed['market_data']['fdv_to_tvl_ratio']
# fdv_to_tvl_ratio.astype(int) 


#fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']['usd']

# fully_diluted_valuation
total_supply = json_parsed['market_data']['total_supply']
max_supply = json_parsed['market_data']['max_supply']
mcap_to_tvl_ratio = json_parsed['market_data']['mcap_to_tvl_ratio']
total_supply = json_parsed['market_data']['total_supply']
#total_value_locked = json_parsed['market_data']['total_value_locked']['usd']
total_volume = json_parsed['market_data']['total_volume']['usd']

float_rotation_24h = zero_div(total_volume , market_cap)
circulating_cap = current_price * json_parsed['market_data']['circulating_supply']
total_cap = current_price * total_supply


def max_cap(current_price, max_supply):
  """
    Calculation of maximum capitalization 
     Requiring current price and maximum supply
  """
  if max_supply is not None :
    max_cap = current_price * max_supply
  else :
    max_cap = 0
  return max_cap

max_cap = max_cap(current_price, max_supply)



def max_supply_expansion_multiple(circulating_supply, max_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if max_supply is None :
    max_supply_expansion_multiple = 0
    
  elif circulating_supply ==  0:
    max_supply_expansion_multiple == 0
  
  else :
    max_supply_expansion_multiple = max_supply  / circulating_supply
  
  return max_supply_expansion_multiple


max_supply_expansion_multiple = max_supply_expansion_multiple(circulating_supply, max_supply)

def total_supply_expansion_multiple(circulating_supply, total_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if total_supply is None :
    total_supply_expansion_multiple = 0
    
  elif circulating_supply == 0:
    total_supply_expansion_multiple == 0
  
  else :
    total_supply_expansion_multiple = total_supply  / circulating_supply
  
  return total_supply_expansion_multiple


"""
def market_cap_dilution_ratio(fully_diluted_valuation, market_cap):


  if fully_diluted_valuation or market_cap is None :
    market_cap_dilution_ratio == 0
    
  elif fully_diluted_valuation or market_cap is 0:
    market_cap_dilution_ratio == 0

  elif fully_diluted_valuation or market_cap is {}:
    market_cap_dilution_ratio == 0

  else :
    market_cap_dilution_ratio =  fully_diluted_valuation / market_cap
  
  return market_cap_dilution_ratio


market_cap_dilution_ratio = market_cap_dilution_ratio(fully_diluted_valuation, market_cap)
"""

print('')  

circulating_versus_max = circulating_supply/total_supply
dict_custom = {}
#dict_custom['total_supply_expansion_multiple'] = total_supply_expansionWhere_multiple
dict_custom['max_supply_expansion_multiple'] = max_supply_expansion_multiple
dict_custom['float_rotation_24h'] = float_rotation_24h

dict_custom['circulating_versus_max'] = circulating_versus_max


print(dict_custom)

df_market = {}
df_market['market_cap'] = market_cap
#Final been up what is on the national emergency, informative or what basket is something the P is the spaciousness up to Sarah  ankedat1['circulating_supply'] = circulating_supply
df_market['current_price'] = current_price
# df_market['fdv_to_tvl_ratio'] = fdv_to_tvl_ratio#
#df_market['fully_diluted_valuation'] = fully_diluted_valuation
# ankedat1['max_supply'] = max_supply
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_supply'] = total_supply
#df_market['total_value_locked'] = total_value_locked
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_volume'] = total_volume


print(df_market)




print('          ')  
print('PRICE ACTION')  
price_change_percentage_7d = json_parsed['market_data']['price_change_percentage_7d']
price_change_percentage_14d = json_parsed['market_data']['price_change_percentage_14d']
price_change_percentage_30d = json_parsed['market_data']['price_change_percentage_30d']
price_change_percentage_60d = json_parsed['market_data']['price_change_percentage_60d']
price_change_percentage_200d = json_parsed['market_data']['price_change_percentage_200d']
price_change_percentage_1y = json_parsed['market_data']['price_change_percentage_1y']



dict_return = {}
dict_return['price_change_percentage_7d'] = price_change_percentage_7d
dict_return['price_change_percentage_14d'] = price_change_percentage_14d
dict_return['price_change_percentage_30d'] = price_change_percentage_30d
dict_return['price_change_percentage_60d'] = price_change_percentage_60d
dict_return['price_change_percentage_200d'] = price_change_percentage_200d
dict_return['price_change_percentage_1y'] = price_change_percentage_1y

print(dict_return)



category = json_parsed['categories']

print('')  
print('CATEGORIES')  
print(category)
  



description  = [] 
pd.set_option('display.width', 10)
pd.set_option("display.max_rows", None, "display.max_columns", None)
description = json_parsed['description']['en']

print('')  
print('DESCRIPTION: ')
print(description)


links = json_parsed['links']

print('')  
print('LIQUIDITY: ')
print('')  

a = json_parsed['tickers']
data = pd.json_normalize(a,max_level=4)
df = pd.DataFrame(data)

df['pair'] = df['base'] + df['target'] 

df['market_and_volume'] = df['market.name']+ ' (' + df['volume'].round(1).astype(str)+')'
df['Exchanges'] = df.apply(lambda _: ', '.join(df['market_and_volume'] .tolist()), axis=1)
df['Exchanges'][1]

df
# Out:
# WEB Links
#
# Homepage: ['http://www.bitcoin.org', '', '']
# Twitter: https://twitter.com/bitcoin
# Reddit: https://www.reddit.com/r/Bitcoin/
# Chat: ['', '', '']
# CoinGecko: https://www.coingecko.com/en/coins/bitcoin
# Complete list: {'homepage': ['http://www.bitcoin.org', '', ''], 'blockchain_site': ['https://blockchair.com/bitcoin/', 'https://btc.com/', 'https://btc.tokenview.io/', '', '', '', '', '', '', ''], 'official_forum_url': ['https://bitcointalk.org/', '', ''], 'chat_url': ['', '', ''], 'announcement_url': ['', ''], 'twitter_screen_name': 'bitcoin', 'facebook_username': 'bitcoins', 'bitcointalk_thread_identifier': None, 'telegram_channel_identifier': '', 'subreddit_url': 'https://www.reddit.com/r/Bitcoin/', 'repos_url': {'github': ['https://github.com/bitcoin/bitcoin', 'https://github.com/bitcoin/bips'], 'bitbucket': []}}
#
# MARKET DATA
#
#
# {'max_supply_expansion_multiple': 1.0840664633921595, 'float_rotation_24h': 0.03724049486465465, 'circulating_versus_max': 0.9224526666666667}
# {'market_cap': 517934271016, 'current_price': 26738, 'mcap_to_tvl_ratio': None, 'total_supply': 21000000.0, 'total_volume': 19288128560}
#
# PRICE ACTION
# {'price_change_percentage_7d': -9.54494, 'price_change_percentage_14d': -8.88675, 'price_change_percentage_30d': -10.67196, 'price_change_percentage_60d': 10.34288, 'price_change_percentage_200d': 38.1915, 'price_change_percentage_1y': -6.87199}
#
# CATEGORIES
# ['Cryptocurrency', 'Layer 1 (L1)']
#
# DESCRIPTION:
# Bitcoin is the first successful internet money based on peer-to-peer technology; whereby no central bank or authority is involved in the transaction and production of the Bitcoin currency. It was created by an anonymous individual/group under the name, Satoshi Nakamoto. The source code is available publicly as an open source project, anybody can look at it and be part of the developmental process.
#
# Bitcoin is changing the way we see money as we speak. The idea was to produce a means of exchange, independent of any central authority, that could be transferred electronically in a secure, verifiable and immutable way. It is a decentralized peer-to-peer internet currency making mobile payment easy, very low transaction fees, protects your identity, and it works anywhere all the time with no central authority and banks.
#
# Bitcoin is designed to have only 21 million BTC ever created, thus making it a deflationary currency. Bitcoin uses the <a href="https://www.coingecko.com/en?hashing_algorithm=SHA-256">SHA-256</a> hashing algorithm with an average transaction confirmation time of 10 minutes. Miners today are mining Bitcoin using ASIC chip dedicated to only mining Bitcoin, and the hash rate has shot up to peta hashes.
#
# Being the first successful online cryptography currency, Bitcoin has inspired other alternative currencies such as <a href="https://www.coingecko.com/en/coins/litecoin">Litecoin</a>, <a href="https://www.coingecko.com/en/coins/peercoin">Peercoin</a>, <a href="https://www.coingecko.com/en/coins/primecoin">Primecoin</a>, and so on.
#
# The cryptocurrency then took off with the innovation of the turing-complete smart contract by <a href="https://www.coingecko.com/en/coins/ethereum">Ethereum</a> which led to the development of other amazing projects such as <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a>, and even crypto-collectibles such as <a href="https://www.coingecko.com/buzz/ethereum-still-king-dapps-cryptokitties-need-1-billion-on-eos">CryptoKitties</a>.
#
# LIQUIDITY:
#      base  \
# 0     BTC
# 1     BTC
# 2     BTC
# 3     BTC
# 4     BTC
# 5     BTC
# 6     BTC
# 7    WBTC
# 8     BTC
# 9     BTC
# 10    BTC
# 11    BTC
# 12    BTC
# 13    BTC
# 14    BTC
# 15    BTC
# 16    BTC
# 17    ETH
# 18    BTC
# 19    BTC
# 20    BTC
# 21   WBTC
# 22    BTC
# 23    BTC
# 24    BTC
# 25    ETH
# 26    BTC
# 27    ETH
# 28    BTC
# 29    BTC
# 30    BTC
# 31    BTC
# 32    BTC
# 33    ETH
# 34    BTC
# 35    BTC
# 36    BTC
# 37    BTC
# 38    BTC
# 39    BTC
# 40    ETH
# 41    BTC
# 42    FNB
# 43    BTC
# 44    BTC
# 45    BTC
# 46    XRP
# 47    BTC
# 48    ETH
# 49    LTC
# 50    XRP
# 51    BTC
# 52    BTC
# 53    XRP
# 54    BTC
# 55    ETH
# 56    ETH
# 57    BTC
# 58    BTC
# 59    ETH
# 60    BTC
# 61    BTC
# 62    BTC
# 63    ETH
# 64    ETH
# 65   WBTC
# 66    BTC
# 67    LTC
# 68    BNB
# 69  MATIC
# 70    LTC
# 71    BTC
# 72    ETH
# 73    BTC
# 74    BTC
# 75    BTC
# 76  MATIC
# 77    BTC
# 78    ETH
# 79    BTC
# 80    ETH
# 81    BTC
# 82    BTC
# 83    BTC
# 84    BTC
# 85    BTC
# 86    SOL
# 87    TRX
# 88    ETH
# 89    XBT
# 90    BTC
# 91    BNB
# 92   LINK
# 93    BTC
# 94    BTC
# 95    TRX
# 96   DOGE
# 97    LTC
# 98    BTC
# 99    BTC
#
#    target  \
# 0    USDT
# 1    USDT
# 2     USD
# 3     USD
# 4    USDT
# 5    USDT
# 6    USDT
# 7     BTC
# 8    USDT
# 9     USD
# 10    USD
# 11   USDT
# 12    USD
# 13   USDT
# 14   USDT
# 15    USD
# 16   BUSD
# 17    BTC
# 18   USDT
# 19   BUSD
# 20   USDT
# 21    BTC
# 22   USDT
# 23   USDT
# 24    USD
# 25    BTC
# 26   USDT
# 27    BTC
# 28   USDT
# 29   USDT
# 30    USD
# 31    USD
# 32   USDT
# 33    BTC
# 34   USDT
# 35   USDT
# 36   USDT
# 37    JPY
# 38    GBP
# 39   USDT
# 40    BTC
# 41    USD
# 42    BTC
# 43   USDC
# 44   BUSD
# 45   USDT
# 46    BTC
# 47   USDT
# 48    BTC
# 49    BTC
# 50    BTC
# 51   USDT
# 52   USDT
# 53    BTC
# 54   USDC
# 55    BTC
# 56    BTC
# 57   USDT
# 58   USDT
# 59    BTC
# 60   USDC
# 61   USDC
# 62   USDC
# 63    BTC
# 64    BTC
# 65    BTC
# 66   USDC
# 67    BTC
# 68    BTC
# 69    BTC
# 70    BTC
# 71   USDC
# 72    BTC
# 73   USDT
# 74    GBP
# 75   USDT
# 76    BTC
# 77   USDT
# 78    BTC
# 79   USDC
# 80    BTC
# 81   USDT
# 82   USDC
# 83    XRP
# 84   USDC
# 85   USDT
# 86    BTC
# 87    BTC
# 88    BTC
# 89    AUD
# 90   USDC
# 91    BTC
# 92    BTC
# 93   USDT
# 94   USDT
# 95    BTC
# 96    BTC
# 97    BTC
# 98   TUSD
# 99   USDC
#
#             last  \
# 0   2.672607e+04
# 1   2.671770e+04
# 2   2.673116e+04
# 3   2.674400e+04
# 4   2.671909e+04
# 5   2.671085e+04
# 6   2.670267e+04
# 7   1.000500e+00
# 8   2.671702e+04
# 9   2.674400e+04
# 10  2.677402e+04
# 11  2.671536e+04
# 12  2.673600e+04
# 13  2.671810e+04
# 14  2.671998e+04
# 15  2.673194e+04
# 16  2.673730e+04
# 17  6.753700e-02
# 18  2.671942e+04
# 19  2.671698e+04
# 20  2.671592e+04
# 21  1.000790e+00
# 22  2.671000e+04
# 23  2.671895e+04
# 24  2.673407e+04
# 25  6.750000e-02
# 26  2.672717e+04
# 27  6.758862e-02
# 28  2.671325e+04
# 29  2.671399e+04
# 30  2.674001e+04
# 31  2.673568e+04
# 32  2.672252e+04
# 33  6.749800e-02
# 34  2.671680e+04
# 35  2.674200e+04
# 36  2.671783e+04
# 37  3.632267e+06
# 38  2.148900e+04
# 39  2.671896e+04
# 40  6.758600e-02
# 41  2.674473e+04
# 42  2.992000e-05
# 43  2.673229e+04
# 44  2.672430e+04
# 45  2.671615e+04
# 46  1.606000e-05
# 47  2.672482e+04
# 48  6.758800e-02
# 49  2.996000e-03
# 50  1.606000e-05
# 51  2.671900e+04
# 52  2.671485e+04
# 53  1.609900e-05
# 54  2.674236e+04
# 55  6.758000e-02
# 56  6.760299e-02
# 57  2.671750e+04
# 58  2.671946e+04
# 59  6.758200e-02
# 60  2.674189e+04
# 61  2.672900e+04
# 62  2.673531e+04
# 63  6.745600e-02
# 64  6.752801e-02
# 65  1.000500e+00
# 66  2.672476e+04
# 67  3.000000e-03
# 68  1.152200e-02
# 69  3.211980e-05
# 70  2.998880e-03
# 71  2.675000e+04
# 97  3.081546e+03
# 98  9.160440e+00
# 99  1.312578e+02
#
#    trust_score  \
# 0        green
# 1        green
# 2        green
# 3        green
# 4        green
# 5        green
# 6        green
# 7        green
# 8        green
# 9        green
# 10       green
# 11       green
# 12       green
# 13       green
# 14       green
# 15       green
# 16       green
# 17       green
# 18       green
# 19       green
# 20       green
# 21       green
# 22       green
# 23       green
# 24       green
# 25       green
# 26       green
# 27       green
# 28       green
# 29       green
# 30       green
# 31       green
# 32       green
# 33       green
# 34       green
# 35       green
# 36       green
# 37       green
# 38       green
# 39       green
# 40       green
# 41       green
# 42       green
# 43       green
# 44       green
# 45       green
# 46       green
# 47       green
# 48       green
# 49       green
# 50       green
# 51       green
# 52       green
# 53       green
# 54       green
# 55       green
# 56       green
# 57       green
# 58       green
# 59       green
# 60       green
# 61       green
# 62       green
# 63       green
# 64       green
# 65       green
# 66       green
# 67       green
# 68       green
# 69       green
# 70       green
# 71       green
# 72       green
# 73       green
# 74       green
# 75       green
# 76       green
# 77       green
# 78       green
# 79       green
# 80       green
# 81       green
# 82       green
# 83       green
# 84       green
# 85       green
# 86       green
# 87       green
# 88       green
# 89       green
# 90       green
# 91       green
# 92       green
# 93       green
# 94       green
# 95       green
# 96       green
# 97       green
# 98       green
# 99       green
#
#     bid_ask_spread_percentage  \
# 0                    0.010037
# 1                    0.010374
# 2                    0.011871
# 3                    0.037383
# 4                    0.010112
# 5                    0.011459
# 6                    0.010037
# 7                    0.019994
# 8                    0.014005
# 9                    0.050363
# 10                   0.079271
# 11                   0.010374
# 12                   0.014488
# 13                   0.010374
# 14                   0.130950
# 15                   0.119349
# 16                   0.010037
# 17                   0.011481
# 18                   0.010037
# 19                   0.013480
# 20                   0.013294
# 21                   0.069937
# 22                   0.037383
# 23                   0.010037
# 24                   0.021133
# 25                   0.040661
# 26                   0.010710
# 27                   0.011480
# 28                   0.010037
# 29                   0.010037
# 30                   0.015965
# 31                   0.010486
# 32                   0.010037
# 33                   0.029638
# 34                   0.019998
# 35                   0.010374
# 36                   0.010037
# 37                   0.048370
# 38                   0.069359
# 39                   0.203543
# 40                   0.010358
# 41                   0.029324
# 42                   0.167001
# 43                   0.011497
# 44                   0.100803
# 45                   0.036972
# 46                   0.061996
# 47                   0.010449
# 48                   0.012963
# 49                   0.100067
# 50                   0.062228
# 51                   0.013099
# 52                   0.034278
# 53                   0.372255
# 54                   0.232427
# 55                   0.029586
# 56                   0.011479
# 57                   0.011230
# 58                   0.022830
# 59                   0.011480
# 60                   0.024875
# 61                   0.010374
# 62                   0.026845
# 63                   0.314665
# 64                   0.112470
# 65                   0.079928
# 66                   0.020005
# 67                   0.033333
# 68                   0.018682
# 69                   0.043015
# 70                   0.020005
# 71                   0.011581
# 72                   0.014799
# 73                   0.010037
# 74                   0.015825
# 75                   0.020043
# 76                   0.155618
# 77                   0.010037
# 78                   0.017775
# 79                   0.010037
# 80                   0.017398
# 81                   0.139400
# 82                   0.010075
# 83                   0.163145
# 84                   0.075086
# 14                 https://coinsbit.io/trade/BTC_USDT
# 15          https://go.coinmetro.com/exchange/btc-usd
# 16  https://www.binance.com/en/trade/BTC_BUSD?ref=...
# 17  https://www.binance.com/en/trade/ETH_BTC?ref=3...
# 18             https://www.mexc.com/exchange/BTC_USDT
# 19                  https://www.xt.com/trade/btc_busd
# 20        https://www.bitget.com/en/spot/BTCUSDT_SPBL
# 21     https://www.digifinex.com/en-ww/trade/BTC/WBTC
# 22  https://trading.bitfinex.com/t/BTC:UST?type=ex...
# 23              https://www.bitrue.com/trade/btc_usdt
# 24           https://www.binance.us/trade/pro/BTC_USD
# 25          https://www.bitstamp.net/markets/eth/btc/
# 26    https://crypto.com/exchange/trade/spot/BTC_USDT
# 27                                               None
# 28     https://www.digifinex.com/en-ww/trade/USDT/BTC
# 29               https://www.lbank.com/trade/btc_usdt
# 30                                               None
# 31     https://crypto.com/exchange/trade/spot/BTC_USD
# 32          https://www.bybit.com/trade/spot/BTC/USDT
# 33  https://trading.bitfinex.com/t/ETH:BTC?type=ex...
# 34              https://c-patex.com/exchange/BTC/USDT
# 35              https://www.kucoin.com/trade/BTC-USDT
# 36  https://www.bitmart.com/trade/en?layout=basic&...
# 37             https://bitflyer.com/en-jp/ex/simpleex
# 38          https://www.bitstamp.net/markets/btc/gbp/
# 39                                               None
# 40                   https://www.xt.com/trade/eth_btc
# 41    https://cryptology.com/app/next/trading/BTC_USD
# 42  https://www.finexbox.com/Home/Orders/market/pa...
# 43     https://www.digifinex.com/en-ww/trade/USDC/BTC
# 44                                               None
# 45          https://www.binance.us/trade/pro/BTC_USDT
# 46  https://www.binance.com/en/trade/XRP_BTC?ref=3...
# 47  https://exchange.pointpay.io/trade-classic/BTC...
# 48  https://www.bitmart.com/trade/en?layout=basic&...
# 49  https://exchange.pointpay.io/trade-classic/LTC...
# 50                     https://txbit.io/Trade/XRP/BTC
# 51          https://pro.kraken.com/app/trade/BTC-USDT
# 52            https://pro.coinbase.com/trade/BTC-USDT
# 53      https://www.digifinex.com/en-ww/trade/BTC/XRP
# 54   https://cryptology.com/app/next/trading/BTC_USDC
# 55             https://pro.coinbase.com/trade/ETH-BTC
# 56                     https://txbit.io/Trade/ETH/BTC
# 57  https://www.delta.exchange/app/spot/trade/BTC/...
# 58              https://phemex.com/spot/trade/BTCUSDT
# 59               https://www.bitrue.com/trade/eth_btc
# 60          https://pro.kraken.com/app/trade/BTC-USDC
# 61            https://www.okx.com/trade-spot/btc-usdc
# 62          https://www.bybit.com/trade/spot/BTC/USDC
# 63                                               None
# 64                  https://exmo.com/en/trade/ETH_BTC
# 65              https://www.bitrue.com/trade/wbtc_btc
# 66               https://bingx.com/en-us/spot/BTCUSDC
# 67                 https://whitebit.com/trade/LTC_BTC
# 68  https://www.binance.com/en/trade/BNB_BTC?ref=3...
# 69  https://www.bitmart.com/trade/en?layout=basic&...
# 70                  https://coinsbit.io/trade/LTC_BTC
# 71              https://www.kucoin.com/trade/BTC-USDC
# 72             https://www.okx.com/trade-spot/eth-btc
# 73              https://latoken.com/exchange/USDT-BTC
# 74           https://pro.kraken.com/app/trade/BTC-GBP
# 75               https://bingx.com/en-us/spot/BTCUSDT
# 76  https://cryptology.com/app/next/trading/MATIC_BTC
# 77  https://www.coinex.com/trading?currency=USDT&d...
# 78  https://exchange.pointpay.io/trade-classic/ETH...
# 79  https://www.binance.com/en/trade/BTC_USDC?ref=...
# 80      https://www.digifinex.com/en-ww/trade/BTC/ETH
# 81                     https://big.one/trade/BTC-USDT
# 82               https://www.lbank.com/trade/btc_usdc
# 83      https://trade.coinfield.com/pro/trade/BTC-XRP
# 84        https://www.bitget.com/en/spot/BTCUSDC_SPBL
# 85                      https://ace.io/trade/BTC/USDT
# 86              https://www.mexc.com/exchange/SOL_BTC
# 87                 https://whitebit.com/trade/TRX_BTC
# 88                                               None
# 89      https://www.independentreserve.com/market#xbt
# 90                                               None
# 91  https://www.bitmart.com/trade/en?layout=basic&...
# 92  https://www.bitmart.com/trade/en?layout=basic&...
# 93           https://www.coinstore.com/#/spot/BTCUSDT
# 94                    https://qmall.io/trade/BTC_USDT
# 95  https://www.bitmart.com/trade/en?layout=basic&...
# 96                https://whitebit.com/trade/DOGE_BTC
# 97  https://www.bitmart.com/trade/en?layout=basic&...
# 98  https://www.bitmart.com/trade/en?layout=basic&...
# 99                https://www.bkex.com/trade/BTC_USDC
#
#    token_info_url  \
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
# 32           None
# 33           None
# 34           None
# 35           None
# 36           None
# 37           None
# 38           None
# 39           None
# 40           None
# 41           None
# 42           None
# 43           None
# 44           None
# 45           None
# 46           None
# 47           None
# 48           None
# 49           None
# 50           None
# 51           None
# 52           None
# 53           None
# 54           None
# 55           None
# 56           None
# 57           None
# 58           None
# 59           None
# 60           None
# 61           None
# 62           None
# 63           None
# 64           None
# 65           None
# 66           None
# 67           None
# 68           None
# 69           None
# 70           None
# 71           None
# 72           None
# 73           None
# 74           None
# 75           None
# 76           None
# 77           None
# 78           None
# 79           None
# 80           None
# 81           None
# 82           None
# 83           None
# 84           None
# 85           None
# 86           None
# 87           None
# 88           None
# 89           None
# 90           None
# 91           None
# 92           None
# 93           None
# 94           None
# 95           None
# 96           None
# 97           None
# 98           None
# 99           None
#
#             coin_id  \
# 0           bitcoin
# 1           bitcoin
# 2           bitcoin
# 3           bitcoin
# 4           bitcoin
# 5           bitcoin
# 6           bitcoin
# 7   wrapped-bitcoin
# 8           bitcoin
# 9           bitcoin
# 10          bitcoin
# 11          bitcoin
# 12          bitcoin
# 13          bitcoin
# 14          bitcoin
# 15          bitcoin
# 16          bitcoin
# 17         ethereum
# 18          bitcoin
# 19          bitcoin
# 20          bitcoin
# 21  wrapped-bitcoin
# 22          bitcoin
# 23          bitcoin
# 24          bitcoin
# 25         ethereum
# 26          bitcoin
# 27         ethereum
# 28          bitcoin
# 29          bitcoin
# 30          bitcoin
# 31          bitcoin
# 32          bitcoin
# 33         ethereum
# 34          bitcoin
# 35          bitcoin
# 36          bitcoin
# 37          bitcoin
# 38          bitcoin
# 39          bitcoin
# 40         ethereum
# 41          bitcoin
# 42   finexbox-token
# 43          bitcoin
# 44          bitcoin
# 45          bitcoin
# 46           ripple
# 47          bitcoin
# 48         ethereum
# 49         litecoin
# 50           ripple
# 51          bitcoin
# 52          bitcoin
# 53           ripple
# 54          bitcoin
# 55         ethereum
# 56         ethereum
# 57          bitcoin
# 58          bitcoin
# 59         ethereum
# 60          bitcoin
# 61          bitcoin
# 62          bitcoin
# 63         ethereum
# 64         ethereum
# 65  wrapped-bitcoin
# 66          bitcoin
# 67         litecoin
# 68      binancecoin
# 69    matic-network
# 70         litecoin
# 71          bitcoin
# 72         ethereum
# 73          bitcoin
# 74          bitcoin
# 75          bitcoin
# 76    matic-network
# 77          bitcoin
# 78         ethereum
# 79          bitcoin
# 80         ethereum
# 81          bitcoin
# 82          bitcoin
# 83          bitcoin
# 84          bitcoin
# 85          bitcoin
# 86           solana
# 87             tron
# 88         ethereum
# 89          bitcoin
# 90          bitcoin
# 91      binancecoin
# 92        chainlink
# 93          bitcoin
# 94          bitcoin
# 95             tron
# 96         dogecoin
# 97         litecoin
# 98          bitcoin
# 99          bitcoin
#
#    target_coin_id  \
# 0          tether
# 1          tether
# 2             NaN
# 3             NaN
# 4          tether
# 5          tether
# 6          tether
# 7         bitcoin
# 8          tether
# 9             NaN
# 10            NaN
# 11         tether
# 12            NaN
# 13         tether
# 14         tether
# 15            NaN
# 16    binance-usd
# 17        bitcoin
# 18         tether
# 19    binance-usd
# 20         tether
# 21        bitcoin
# 22         tether
# 23         tether
# 24            NaN
# 25        bitcoin
# 26         tether
# 27        bitcoin
# 28         tether
# 29         tether
# 30            NaN
# 31            NaN
# 32         tether
# 33        bitcoin
# 34         tether
# 35         tether
# 36         tether
# 37            NaN
# 38            NaN
# 39         tether
# 40        bitcoin
# 41            NaN
# 42        bitcoin
# 43       usd-coin
# 44    binance-usd
# 45         tether
# 46        bitcoin
# 47         tether
# 48        bitcoin
# 49        bitcoin
# 50        bitcoin
# 51         tether
# 52         tether
# 53        bitcoin
# 54       usd-coin
# 55        bitcoin
# 56        bitcoin
# 57         tether
# 58         tether
# 59        bitcoin
# 60       usd-coin
# 61       usd-coin
# 62       usd-coin
# 63        bitcoin
# 64        bitcoin
# 65        bitcoin
# 66       usd-coin
# 67        bitcoin
# 68        bitcoin
# 69        bitcoin
# 70        bitcoin
# 71       usd-coin
# 72        bitcoin
# 73         tether
# 74            NaN
# 75         tether
# 76        bitcoin
# 77         tether
# 78        bitcoin
# 79       usd-coin
# 80        bitcoin
# 81         tether
# 82       usd-coin
# 83         ripple
# 84       usd-coin
# 85         tether
# 86        bitcoin
# 87        bitcoin
# 88        bitcoin
# 89            NaN
# 90       usd-coin
# 91        bitcoin
# 92        bitcoin
# 93         tether
# 94         tether
# 95        bitcoin
# 96        bitcoin
# 97        bitcoin
# 98       true-usd
# 99       usd-coin
#
#             market.name  \
# 0               Binance
# 1               Gate.io
# 2     Coinbase Exchange
# 3              Bitfinex
# 4                XT.COM
# 5                 BTCEX
# 6                 Tidex
# 7               Binance
# 8              WhiteBIT
# 9              Bitstamp
# 10              Gate.io
# 11                 BKEX
# 12               Kraken
# 13                  OKX
# 14             Coinsbit
# 15            Coinmetro
# 16              Binance
# 17              Binance
# 18          MEXC Global
# 19               XT.COM
# 20               Bitget
# 21            DigiFinex
# 22             Bitfinex
# 23               Bitrue
# 24           Binance US
# 25             Bitstamp
# 26  Crypto.com Exchange
# 27                Tidex
# 28            DigiFinex
# 29                LBank
# 30               Gemini
# 31  Crypto.com Exchange
# 32                Bybit
# 33             Bitfinex
# 34              C-Patex
# 35               KuCoin
# 36              BitMart
# 37             bitFlyer
# 38             Bitstamp
# 39            Dex-Trade
# 40               XT.COM
# 41           Cryptology
# 42             FinexBox
# 43            DigiFinex
# 44            Dex-Trade
# 45           Binance US
# 46              Binance
# 47             PointPay
# 48              BitMart
# 49             PointPay
# 50                Txbit
# 51               Kraken
# 52    Coinbase Exchange
# 53            DigiFinex
# 54           Cryptology
# 55    Coinbase Exchange
# 56                Txbit
# 57       Delta Exchange
# 58               Phemex
# 59               Bitrue
# 60               Kraken
# 61                  OKX
# 62                Bybit
# 63                  P2B
# 64                 EXMO
# 65               Bitrue
# 66                BingX
# 67             WhiteBIT
# 68              Binance
# 69              BitMart
# 70             Coinsbit
# 71               KuCoin
# 72                  OKX
# 73              LATOKEN
# 74               Kraken
# 75                BingX
# 76           Cryptology
# 77               CoinEx
# 78             PointPay
# 79              Binance
# 80            DigiFinex
# 81               BigONE
# 82                LBank
# 83            Coinfield
# 84               Bitget
# 85                  Ace
# 86          MEXC Global
# 87             WhiteBIT
# 88            Dex-Trade
# 89  Independent Reserve
# 90                Tidex
# 91              BitMart
# 92              BitMart
# 93            Coinstore
# 94                QMall
# 95              BitMart
# 96             WhiteBIT
# 97              BitMart
# 98              BitMart
# 99                 BKEX
#
#       market.identifier  \
# 0               binance
# 1                  gate
# 2                  gdax
# 3              bitfinex
# 4                    xt
# 5                 btcex
# 6                 tidex
# 7               binance
# 8              whitebit
# 9              bitstamp
# 10                 gate
# 11                 bkex
# 12               kraken
# 13                 okex
# 14             coinsbit
# 15           coin_metro
# 16              binance
# 17              binance
# 18                  mxc
# 19                   xt
# 20               bitget
# 21            digifinex
# 22             bitfinex
# 23               bitrue
# 24           binance_us
# 25             bitstamp
# 26           crypto_com
# 27                tidex
# 28            digifinex
# 29                lbank
# 30               gemini
# 31           crypto_com
# 32           bybit_spot
# 33             bitfinex
# 34              c_patex
# 35               kucoin
# 36              bitmart
# 37             bitflyer
# 38             bitstamp
# 39             dextrade
# 40                   xt
# 41           cryptology
# 42             finexbox
# 43            digifinex
# 44             dextrade
# 45           binance_us
# 46              binance
# 47             pointpay
# 48              bitmart
# 49             pointpay
# 50                txbit
# 51               kraken
# 52                 gdax
# 53            digifinex
# 54           cryptology
# 55                 gdax
# 56                txbit
# 57           delta_spot
# 58               phemex
# 59               bitrue
# 60               kraken
# 61                 okex
# 62           bybit_spot
# 63               p2pb2b
# 64                 exmo
# 65               bitrue
# 66                bingx
# 67             whitebit
# 68              binance
# 69              bitmart
# 70             coinsbit
# 71               kucoin
# 72                 okex
# 73              latoken
# 74               kraken
# 75                bingx
# 76           cryptology
# 77               coinex
# 78             pointpay
# 79              binance
# 80            digifinex
# 81               bigone
# 82                lbank
# 83            coinfield
# 84               bitget
# 85                  ace
# 86                  mxc
# 87             whitebit
# 88             dextrade
# 89  independent_reserve
# 90                tidex
# 91              bitmart
# 92              bitmart
# 93            coinstore
# 94                qmall
# 95              bitmart
# 96             whitebit
# 97              bitmart
# 98              bitmart
# 99                 bkex
#
#     market.has_trading_incentive  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# 5                          False
# 6                          False
# 7                          False
# 8                          False
# 9                          False
# 10                         False
# 11                         False
# 12                         False
# 13                         False
# 14                         False
# 15                         False
# 16                         False
# 17                         False
# 18                         False
# 19                         False
# 20                         False
# 21                         False
# 22                         False
# 23                         False
# 24                         False
# 25                         False
# 26                         False
# 27                         False
# 28                         False
# 29                         False
# 30                         False
# 31                         False
# 32                         False
# 33                         False
# 34                         False
# 35                         False
# 36                         False
# 37                         False
# ...
# 20         123475.000000
# 21           9860.000000
# 22           4028.000000
# 23         119883.000000
# 24          49719.000000
# 25            603.843000
# 26          20506.000000
# 27           5612.000000
# 28          63134.000000
# 29          93340.000000
# 30           9095.000000
# 31          27485.000000
# 32         131607.000000
# 33           1606.000000
# 34           1540.000000
# 35          69109.000000
# 36          87836.000000
# 37          28447.000000
# 38            760.308000
# 39          11812.000000
# 40           6265.000000
# 41           4441.000000
# 42            174.835000
# 43           2135.000000
# 44            143.868000
# 45           9253.000000
# 46          10948.000000
# 47          10803.000000
# 48           1757.000000
# 49           2822.000000
# 50            126.923000
# 51           5054.000000
# 52          20929.000000
# 53            625.131000
# 54            970.084000
# 55           3971.000000
# 56           1003.000000
# 57             66.666000
# 58           5655.000000
# 59          71667.000000
# 60           1832.000000
# 61           6886.000000
# 62          25755.000000
# 63           1070.000000
# 64           8687.000000
# 65           5777.000000
# 66          10566.000000
# 67            127.179000
# 68           8284.000000
# 69             83.033000
# 70            741.175000
# 71           5447.000000
# 72           4378.000000
# 73          13523.000000
# 74           2375.000000
# 75         112050.000000
# 76            885.753000
# 77           8376.000000
# 78            617.569000
# 79          20185.000000
# 80           3258.000000
# 81          19732.000000
# 82          13766.000000
# 83            428.970000
# 84          10851.000000
# 85           3902.000000
# 86             68.961000
# 87             34.748341
# 88           1793.000000
# 89            255.373000
# 90            667.878000
# 91            212.867000
# 92            193.075000
# 93          44610.000000
# 94          17927.000000
# 95             48.381771
# 96             58.726000
# 97            136.779000
# 98            135.552000
# 99           1947.000000
#
#     converted_volume.usd  \
# 0             1750662268
# 1              177356579
# 2              488831191
# 3               48711856
# 4              349889373
# 5              228232585
# 6              165121657
# 7                6384978
# 8              371971655
# 9              129169830
# 10              10232000
# 11             227592634
# 12             147421947
# 13             354305272
# 14             114624335
# 15                565743
# 16             281657093
# 17             109287204
# 18             236839065
# 19               7336121
# 20             223116145
# 21              17816521
# 22               7277999
# 23             216627442
# 24              89840703
# 25               1089636
# 26              37055774
# 27              10141024
# 28             114081917
# 29             168664522
# 30              16435103
# 31              49670950
# 32             237811266
# 33               2901738
# 34               2782767
# 35             124866611
# 36             158681852
# 37              51403337
# 38               1373862
# 39              21343982
# 40              11320243
# 41               8025502
# 42                315925
# 43               3857185
# 44                259968
# 45              16719473
# 46              19732995
# 47              19519380
# 48               3174814
# 49               5098951
# 50                229348
# 51               9134309
# 52              37814332
# 53               1129601
# 54               1752926
# 55               7174739
# 56               1811946
# 57                120465
# 58              10220140
# 59             129500494
# 60               3310262
# 61              12443149
# 62              46538964
# 63               1933076
# 64              15697173
# 65              10438414
# 66              19090616
# 67                229810
# 68              14955091
# 69                150005
# 70               1339291
# 71               9841494
# 72               7911087
# 73              24435716
# 74               4292343
# 75             202452349
# 76               1600542
# 77              15137545
# 78               1115827
# 79              36425870
# 80               5887660
# 81              35659816
# 82              24875575
# 83                773955
# 84              19607598
# 85               7050258
# 86                124612
# 87                 62790
# 88               3240523
# 89                461455
# 90               1206973
# 91                384558
# 92                348803
# 93              80601731
# 94              32385891
# 95                 87405
# 96                106117
# 97                247100
# 98                244941
# 99               3518597
#
#         pair  \
# 0    BTCUSDT
# 1    BTCUSDT
# 2     BTCUSD
# 3     BTCUSD
# 4    BTCUSDT
# 5    BTCUSDT
# 6    BTCUSDT
# 7    WBTCBTC
# 8    BTCUSDT
# 9     BTCUSD
# 10    BTCUSD
# 11   BTCUSDT
# 12    BTCUSD
# 13   BTCUSDT
# 14   BTCUSDT
# 15    BTCUSD
# 16   BTCBUSD
# 17    ETHBTC
# 18   BTCUSDT
# 19   BTCBUSD
# 20   BTCUSDT
# 21   WBTCBTC
# 22   BTCUSDT
# 23   BTCUSDT
# 24    BTCUSD
# 25    ETHBTC
# 26   BTCUSDT
# 27    ETHBTC
# 28   BTCUSDT
# 29   BTCUSDT
# 30    BTCUSD
# 31    BTCUSD
# 32   BTCUSDT
# 33    ETHBTC
# 34   BTCUSDT
# 35   BTCUSDT
# 36   BTCUSDT
# 37    BTCJPY
# 38    BTCGBP
# 39   BTCUSDT
# 40    ETHBTC
# 41    BTCUSD
# 42    FNBBTC
# 43   BTCUSDC
# 44   BTCBUSD
# 45   BTCUSDT
# 46    XRPBTC
# 47   BTCUSDT
# 48    ETHBTC
# 49    LTCBTC
# 50    XRPBTC
# 51   BTCUSDT
# 52   BTCUSDT
# 53    XRPBTC
# 54   BTCUSDC
# 55    ETHBTC
# 56    ETHBTC
# 57   BTCUSDT
# 58   BTCUSDT
# 59    ETHBTC
# 60   BTCUSDC
# 61   BTCUSDC
# 62   BTCUSDC
# 63    ETHBTC
# 64    ETHBTC
# 65   WBTCBTC
# 66   BTCUSDC
# 67    LTCBTC
# 68    BNBBTC
# 69  MATICBTC
# 70    LTCBTC
# 71   BTCUSDC
# 72    ETHBTC
# 73   BTCUSDT
# 74    BTCGBP
# 75   BTCUSDT
# 76  MATICBTC
# 77   BTCUSDT
# 78    ETHBTC
# 79   BTCUSDC
# 80    ETHBTC
# 81   BTCUSDT
# 82   BTCUSDC
# 83    BTCXRP
# 84   BTCUSDC
# 85   BTCUSDT
# 86    SOLBTC
# 87    TRXBTC
# 88    ETHBTC
# 89    XBTAUD
# 90   BTCUSDC
# 91    BNBBTC
# 92   LINKBTC
# 93   BTCUSDT
# 94   BTCUSDT
# 95    TRXBTC
# 96   DOGEBTC
# 97    LTCBTC
# 98   BTCTUSD
# 99   BTCUSDC
#
#                market_and_volume  \
# 0              Binance (65453.1)
# 1               Gate.io (6698.5)
# 2    Coinbase Exchange (18286.9)
# 3              Bitfinex (1821.4)
# 4               XT.COM (13207.1)
# 5                 BTCEX (8618.5)
# 6                 Tidex (6176.7)
# 7                Binance (238.6)
# 8             WhiteBIT (13908.3)
# 9              Bitstamp (4829.9)
# 10               Gate.io (387.0)
# 11                 BKEX (8533.4)
# 12               Kraken (5514.0)
# 13                 OKX (13401.2)
# 14             Coinsbit (4285.4)
# 15              Coinmetro (21.2)
# 16             Binance (10531.0)
# 17             Binance (60496.9)
# 18          MEXC Global (8856.1)
# 19                XT.COM (277.2)
# 20               Bitget (8416.5)
# 21             DigiFinex (665.7)
# 22              Bitfinex (272.2)
# 23               Bitrue (8099.3)
# 24           Binance US (3360.5)
# 25              Bitstamp (603.6)
# 26  Crypto.com Exchange (1384.9)
# 27                Tidex (5610.0)
# 28            DigiFinex (4266.2)
# 29                LBank (6307.2)
# 30                Gemini (614.6)
# 31  Crypto.com Exchange (1857.9)
# 32                Bybit (8891.4)
# 33             Bitfinex (1607.8)
# 34               C-Patex (104.0)
# 35               KuCoin (4665.3)
# 36              BitMart (5934.0)
# 37             bitFlyer (1921.0)
# 38               Bitstamp (51.4)
# 39             Dex-Trade (798.0)
# 40               XT.COM (6325.0)
# 41            Cryptology (300.1)
# 42           FinexBox (394839.6)
# 43             DigiFinex (144.3)
# 44               Dex-Trade (9.7)
# 45            Binance US (625.2)
# 46          Binance (46078492.2)
# 47              PointPay (740.5)
# 48              BitMart (1756.8)
# 49            PointPay (63855.1)
# 50              Txbit (534008.2)
# 51                Kraken (341.5)
# 52    Coinbase Exchange (1414.5)
# 53         DigiFinex (2623764.0)
# 54             Cryptology (65.5)
# 55    Coinbase Exchange (3970.0)
# 56                Txbit (1002.3)
# 57          Delta Exchange (4.5)
# 58                Phemex (382.1)
# 59              Bitrue (71653.8)
# 60                Kraken (123.8)
# 61                   OKX (470.7)
# 62                Bybit (1740.9)
# 63                  P2B (1071.6)
# 64                 EXMO (8693.6)
# 65                Bitrue (390.1)
# 66                 BingX (719.0)
# 67             WhiteBIT (2864.5)
# 68             Binance (48525.1)
# 69            BitMart (174664.0)
# 70            Coinsbit (16699.9)
# 71                KuCoin (368.0)
# 72                  OKX (4422.1)
# 73               LATOKEN (913.8)
# 74                Kraken (160.6)
# 75                BingX (7647.8)
# 76        Cryptology (1863099.1)
# 77                CoinEx (571.9)
# 78              PointPay (624.4)
# 79              Binance (1362.9)
# 80            DigiFinex (3257.8)
# 81               BigONE (1333.1)
# 82                 LBank (931.1)
# 83              Coinfield (29.1)
# 84                Bitget (740.4)
# 85                   Ace (266.3)
# 86          MEXC Global (6014.3)
# 87           WhiteBIT (913915.0)
# 88            Dex-Trade (1793.1)
# 89    Independent Reserve (17.2)
# 90                  Tidex (45.2)
# 91              BitMart (1247.7)
# 92             BitMart (53083.2)
# 93            Coinstore (3040.0)
# 94                QMall (1224.0)
# 95           BitMart (1273198.0)
# 96          WhiteBIT (1475130.0)
# 97              BitMart (3081.5)
# 98                 BitMart (9.2)
# 99                  BKEX (131.3)
#
#                                             Exchanges
# 0   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 1   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 2   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 3   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 4   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 5   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 6   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 7   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 8   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 9   Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 10  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 11  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 12  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 13  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 14  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 15  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 16  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 17  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 18  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 19  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 20  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 21  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 22  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 23  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 24  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 25  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 26  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 27  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 28  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 29  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 30  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 31  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 32  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 33  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 34  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 35  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 36  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 37  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 38  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 39  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 40  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 41  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 42  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 43  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 44  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 45  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 46  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 47  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 48  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 49  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 50  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 51  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 52  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 53  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 54  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 55  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 56  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 57  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 58  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 59  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 60  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 61  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 62  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 63  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 64  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 65  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 66  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 67  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 68  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 69  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 70  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 71  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 72  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 73  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 74  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 75  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 76  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 77  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 78  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 79  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 80  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 81  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 82  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 83  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 84  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 85  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 86  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 87  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 88  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 89  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 90  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 91  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 92  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 93  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 94  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 95  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 96  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 97  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 98  Binance (65453.1), Gate.io (6698.5), Coinbase ...
# 99  Binance (65453.1), Gate.io (6698.5), Coinbase ...

# %%
#@title Charts

 
import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()

"""
1 - 2 days: 30 minutes
3 - 30 days: 4 hours
31 days and beyond: 4 days
"""
#chart  1
a = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 'max' )
df  = pd.DataFrame(data=a, columns = ['Date','Open','High', 'Low', 'Close'])
df['datetime'] = pd.to_datetime(df['Date'], unit='ms')
fig2 = go.Figure(data=[go.Candlestick(x=df['datetime'],open=df['Open'], high=df['High'],low=df['Low'], close=df['Close'])])                    
fig2.show()

#chart   2
b = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 180 )
df2  = pd.DataFrame(data=b, columns = ['Date','Open','High', 'Low', 'Close'])
df2['datetime'] = pd.to_datetime(df2['Date'], unit='ms')
fig3 = go.Figure(data=[go.Candlestick(x=df2['datetime'],open=df2['Open'], high=df2['High'],low=df2['Low'], close=df2['Close'])])                    
fig3.show()

#chart   3
b = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 30 )
df2  = pd.DataFrame(data=b, columns = ['Date','Open','High', 'Low', 'Close'])
df2['datetime'] = pd.to_datetime(df2['Date'], unit='ms')
fig3 = go.Figure(data=[go.Candlestick(x=df2['datetime'],open=df2['Open'], high=df2['High'],low=df2['Low'], close=df2['Close'])])                    
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0368f7cc-2b5a-4dbc-b245-faa2279b5bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0368f7cc-2b5a-4dbc-b245-faa2279b5bc1")) {                    Plotly.newPlot(                        "0368f7cc-2b5a-4dbc-b245-faa2279b5bc1",                        [{"close":[135.3,91.01,106.4,113.01,114.16,120.5,125.75,128.99,127.98,121.16,119.0,105.99,98.4,106.55,107.25,103.39,95.39,90.8,68.08,85.75,94.0,88.79,91.7,94.13,110.34,103.7,106.75,103.77,111.87,118.78,120.0,125.67,137.76,137.51,123.73
# <ipython-input-17-fb6b5b4e3882>:16: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "y1" (-> marker='1'). The keyword argument will take precedence.
#
# <ipython-input-17-fb6b5b4e3882>:16: UserWarning:
#
# color is redundantly defined by the 'color' keyword argument and the fmt string "y1" (-> color='y'). The keyword argument will take precedence.

# %%
#@title  Project Recent Tweets
import configparser
import tweepy

config_file = "/content/drive/MyDrive/workspace/config.ini"
config_obj = configparser.ConfigParser()
config_obj.read(config_file)

Twitter = config_obj["Twitter_API"]

consumer_key = Twitter["consumer_key"]
consumer_secret = Twitter["consumer_secret"]
access_token = Twitter["access_token"]
access_token_secret = Twitter["access_token_secret"]

pd.set_option('display.width', 10)

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

user_name =str(json_parsed['links']['twitter_screen_name'])

def twitter_rept(user_name):
    """
    
    Generating text data of recent tweets

    """
    
    user =  api.user_timeline(screen_name = user_name )

    for tweet in user:
      
        print(tweet.created_at)

        print(tweet.text)

        print("------------------------------------------------------------------") 
        print(Twitters)

    return 
    
twitter_rept(user_name)
# Out:
# 2023-05-12 05:16:05+00:00
# What happened nine days later? https://t.co/s1dsom2kzc
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-09 04:39:57+00:00
# https://t.co/wRHogK9muz
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-05 16:41:05+00:00
# RT @zerohedge: *MONEY MARKET HOLDINGS HIT RECORD $5.31T IN WEEK ENDED MAY 3:ICI
#
# Up $47BN in one week, up $100BN in two weeks... the bank r…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-05 16:14:10+00:00
# RT @hendry_hugh: Another Guerrilla Acid Capitalist Special...
#
# Today, we hijacked the airwaves of the wonderful Bloomberg studios in New Yo…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-05 15:55:52+00:00
# RT @woonomic: Ethereum is NOT a protocol, you know things like TCP/IP and HTTP.
#
# The crypto world is in a mass psychosis. VC funds have blo…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-05 14:28:36+00:00
# $29,200.
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-05 14:12:18+00:00
# RT @CaitlinLong_: THANK YOU for so forcefully opposing financial censorship &amp; the politicization of banking, @RobertKennedyJr. I am stunned…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-03 22:53:56+00:00
# Money was free for a long time. The @federalreserve is changing that now.
#
# How many more things that should never h… https://t.co/QUWGb4mzFX
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-03 17:26:26+00:00
# RT @DowdEdward: Just going to leave this here for now #BankFailures https://t.co/4mOTzoPFsj
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-03 17:03:53+00:00
# The deepest and most liquid market in the world needs a government program to support liquidity. 😵 https://t.co/rTGRnjJL2e
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-02 18:25:59+00:00
# Judgment and time preference. https://t.co/R62nEv26lj
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-05-02 18:24:56+00:00
# Lots of millionaires. Not a lot of #Bitcoin https://t.co/JJZSzNFpfq
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-29 15:15:15+00:00
# Approximately $16T of $31T of US debt matures within 3 years and 30% within 6 months.
#
# Just wait until inflation st… https://t.co/qOqR8oFcoF
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-28 14:32:05+00:00
# Nearly $1T of credit Card debt in the U.S with an average interest rate of 24.24%.
#
# Much irresponsibility. https://t.co/gO84nmsejP
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-28 14:28:57+00:00
# $29,250.
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-25 03:31:02+00:00
# Which #Bitcoin price will we see first:
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-24 23:02:54+00:00
# RT @TuurDemeester: I just discovered this gorgeous looking primer by @CatoInstitute: "The Risks of CBDCs" https://t.co/1a5d9iu4jA https://t…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-24 22:49:55+00:00
# $100,000. https://t.co/B4LsYiFuIx
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-19 22:14:07+00:00
# Closed. Improve transaction privacy / fungibility in @bitcoincoreorg and the Bitcoin system [meta tracking issues]… https://t.co/n7FldRKsoU
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin
# 2023-04-18 22:34:30+00:00
# Got #Bitcoin? https://t.co/bzkkRp5qXt
# ------------------------------------------------------------------
# Twitter: https://twitter.com/bitcoin

# %% [markdown]
# # Stocks

# %%
#@title Chart
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go


ticker=yahoo_id

data = yf.download(tickers=ticker, period='200d')
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#@title Seasonality

# %% [markdown]
# #Back test

# %%
tickr = yf.Ticker(ticker)

# %%
tickr.shares
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-22-5874b76c0b04> in <cell line: 1>()
# ----> 1 tickr.shares
#
# /usr/local/lib/python3.10/dist-packages/yfinance/ticker.py in shares(self)
#     132     @property
#     133     def shares(self) -> _pd.DataFrame :
# --> 134         return self.get_shares()
#     135
#     136     @property
#
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py in get_shares(self, proxy, as_dict)
#    1251     def get_shares(self, proxy=None, as_dict=False):
#    1252         self._fundamentals.proxy = proxy
# -> 1253         data = self._fundamentals.shares
#    1254         if as_dict:
#    1255             return data.to_dict()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/fundamentals.py in shares(self)
#      38     def shares(self) -> pd.DataFrame:
#      39         if self._shares is None:
# ---> 40             self._scrape_shares(self.proxy)
#      41         return self._shares
#      42
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/fundamentals.py in _scrape_shares(self, proxy)
#      78
#      79     def _scrape_shares(self, proxy):
# ---> 80         self._scrape_basics(proxy)
#      81         # shares outstanding
#      82         try:
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/fundamentals.py in _scrape_basics(self, proxy)
#      46         self._basics_already_scraped = True
#      47
# ---> 48         self._financials_data = self._data.get_json_data_stores('financials', proxy)
#      49         try:
#      50             self._fin_data_quote = self._financials_data['QuoteSummaryStore']
#
# /usr/local/lib/python3.10/dist-packages/yfinance/data.py in wrapped(*args, **kwargs)
#      41         args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      42         kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 43         return func(*args, **kwargs)
#      44
#      45     # copy over the lru_cache extra methods to this wrapper to be able to access them
#
# /usr/local/lib/python3.10/dist-packages/yfinance/data.py in get_json_data_stores(self, sub_page, proxy)
#     316
#     317         # Decrypt!
# --> 318         stores = decrypt_cryptojs_aes_stores(data, keys)
#     319         if stores is None:
#     320             # Maybe Yahoo returned old format, not encrypted
#
# /usr/local/lib/python3.10/dist-packages/yfinance/data.py in decrypt_cryptojs_aes_stores(data, keys)
#     162                 pass
#     163         if not success:
# --> 164             raise Exception("yfinance failed to decrypt Yahoo data response")
#     165
#     166     decoded_stores = json.loads(plaintext)
#
# Exception: yfinance failed to decrypt Yahoo data response

# %%
# get all stock info
tickr.info

# %%
# show holders
tickr.major_holders

# %%
tickr.actions

# %%
tickr.recommendations

# %%
tickr.calendar

# %%
tickr.earnings_dates

# %%
tickr.news
