# %% [markdown]
# <a href="https://colab.research.google.com/github/custom-hyper/Trading-Report/blob/main/Trading_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CoinGecko_id = "bitcoin" #@param {type:"string"}
yahoo_id = "TRBE.V" #@param {type:"string"}

# %% [markdown]
# Archive:

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
#@title
# !pip install statistics --quiet
# !pip install yfinance --quiet
# !pip install pytrends --quiet
# !pip install pycoingecko --quiet
# !pip install pandas --quiet
# !pip install Backtesting --quiet
# !pip install mplfinance --quiet
# !pip install configparser --quiet
# !pip install psycopg2-binary==2.8.6 --quiet
# !pip install tweepy==4.10.1 --quiet
# Out:
# Mounted at /content/drive
#   Preparing metadata (setup.py) ... done
#   Building wheel for statistics (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for Backtesting (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.7/384.7 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for psycopg2-binary (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 2.1 MB/s eta 0:00:00

# %%
#@title Import Project  Dependencies { display-mode: "code" }
import requests
import mplfinance as fplt
from datetime import datetime as dt
from datetime import timedelta
from datetime import date

import time
import json
import seaborn as sns
from google.colab import data_table
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import logging
import sys
from tqdm.notebook import tqdm
import os
import sqlite3 as sq
import psycopg2 as pg
import configparser
from sqlalchemy import create_engine
from pycoingecko import CoinGeckoAPI
import numpy as np
#from __future__ import division

# %% [markdown]
# Highlights

# %%
#@title Set up SQLite { display-mode: "code" }
#@title  Connect { display-mode: "code" }
path = '/content/drive/MyDrive/workspace/pipelines/db/' #@param {type: 'string'
database = "db.sqlite" #@param {type: 'string'
conn_SQLite = sq.connect(path+database)

# %% [markdown]
# # Big  Picture

# %%
#@title
#@title Google Trends
import seaborn as sns
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(10, 5))
# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()


pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
# <ipython-input-5-1b804749d541>:21: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "y1" (-> marker='1'). The keyword argument will take precedence.
#   plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:21: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y1" (-> color='y'). The keyword argument will take precedence.
#   plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:22: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "y2" (-> marker='2'). The keyword argument will take precedence.
#   plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y2" (-> color='y'). The keyword argument will take precedence.
#   plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:23: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "y3" (-> marker='3'). The keyword argument will take precedence.
#   plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
# <ipython-input-5-1b804749d541>:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y3" (-> color='y'). The keyword argument will take precedence.
#   plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title
#@title Crypto Fear & Greed Index

import requests

from datetime import datetime
import time
import json
from google.colab import data_table
import numpy as np
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt



#General Information table
response = requests.get("https://api.alternative.me/fng/?limit=0")
output = response.text
json_parsed = json.loads(output)

df = pd.json_normalize(json_parsed)


df1 = pd.concat([pd.json_normalize(x) for x in df['data'].values.tolist()])
timeseries = df1['timestamp']
df1['date'] = pd.to_datetime(df1['timestamp'], unit = 's')

df_fear_greed = pd.concat([df1['date'], df1['value']], axis=1)
df3 = pd.concat([df1['date'], df1['value_classification']])

# %%
#@title
#@title


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

plt.style.use("dark_background")
#sns.set_theme(style="darkgrid")

#Choose the date range
df_fear_greed = df_fear_greed[(df_fear_greed['date'] > '2016-04-01')]

df_fear_greed['value'] = df_fear_greed['value'].astype(int)

plt.figure(figsize=(20, 5))

sns.lineplot(data=df_fear_greed, linewidth=2.5, x="date", y="value", sort=False)
#sns.lineplot(df_fear_greed=df, linewidth=2.5, x="date", y="TotalCapMrktCurUSD")
plt.title('Crypto Fear & Greed Index Score')

plt.xticks(rotation=45)

plt.legend()


df_fear_greed.head(1)


import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

df_fear_greed['daily_ret'] = df_fear_greed['value'].pct_change(1)

ECDF = sns.displot(df_fear_greed, x="daily_ret", kind="ecdf")

Histogram = df_fear_greed['daily_ret'].hist(bins = 50)


plt.title('Daily Return %')

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Technical Analysis

# %%
#@title S&P 500
import yfinance as yf
import plotly.graph_objects as go


ticker='SPY'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['longName']


data = yf.download(tickers=ticker, period='200d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")

# %%
#@title  VIX
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='^VIX'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['Ticker']

data = yf.download(tickers=ticker, period='200d')
print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")


plt.title('Daily Return %')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Related News – ^VIX
#
# – Dow Falls 300 Points on 'Risk Off' Day
# – Stock Market News for Feb 29, 2024
# – Stock Market News for Feb 28, 2024
# – Stocks Are in a Holding Pattern. It’s All About Inflation Data.
# – Stock Market News for Feb 27, 2024
# – Stock Market News for Feb 26, 2024
# – Energy and Utilities Pop. Fed Minutes and Nvidia Earnings Are Coming Up Soon.
# /usr/local/lib/python3.10/dist-packages/mplfinance/plotting.py:707: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   volumeAxes.set_ylim(vymin,vymax)
# Text(0.5, 1.0, 'Daily Return %')

# %%
#@title

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )


data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# /usr/local/lib/python3.10/dist-packages/mplfinance/plotting.py:707: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   volumeAxes.set_ylim(vymin,vymax)

# %%
#@title Bitcoin
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='BTC-USD'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['shortName']
#ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )
data['daily_ret'] = data['Close'].pct_change(1)


sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Related News – BTC-USD
#
# – China just pulled the country version of a company canceling its quarterly earnings call
# – Home Depot Regional Rental Manager Talks Overcoming Obstacles and Believing in Yourself
# – Sweden Life Insurance Industry Report 2023: Key Trends, Opportunities and Forecasts 2019-2023 and 2024-2028
# – Source.ag Unveils Source Irrigation Control
# – Best-Selling Author Dr. Daniel Amen and Dr. Charles Fay Release New Book 'Raising Mentally Strong Kids'
# – Germany remands Baader-Meinhof suspect over 1990s attacks
# – $4M Grant to Support Displaced Oil and Gas Workers in Contra Costa County

# %%
#@title Ethereum
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='ETH-USD'


ticker_y = yf.Ticker(ticker)
#Name = ticker_y.info['shortName']
#ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass


fplt.plot(
            data,
            type='candle',
            style='mike',
            title =ticker,
            ylabel='Price ($)',
            volume=True,
            mav = (10,20,50,100,200),
            ylabel_lower='Volume',
            )

data['daily_ret'] = data['Close'].pct_change(1)


sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Related News – ETH-USD
#
# – China just pulled the country version of a company canceling its quarterly earnings call
# – Home Depot Regional Rental Manager Talks Overcoming Obstacles and Believing in Yourself
# – Sweden Life Insurance Industry Report 2023: Key Trends, Opportunities and Forecasts 2019-2023 and 2024-2028
# – Source.ag Unveils Source Irrigation Control
# – Best-Selling Author Dr. Daniel Amen and Dr. Charles Fay Release New Book 'Raising Mentally Strong Kids'
# – Germany remands Baader-Meinhof suspect over 1990s attacks
# – $4M Grant to Support Displaced Oil and Gas Workers in Contra Costa County

# %%
#@title Correlation

import numpy as np
import pandas as pd
# Used to grab the stock prices, with yahoo
import pandas_datareader as web
from datetime import datetime
# To visualize the results
import matplotlib.pyplot as plt
import seaborn

start = datetime(2022,9, 1)
symbols_list = [yahoo_id,'SPY', 'QQQ', 'ETH-USD', 'BTC-USD', 'TLT', 'DXY', 'GLD-USD']
#array to store prices
symbols=[]

#array to store prices
symbols=[]
for ticker in symbols_list:

    r = yf.download(tickers=ticker, period='200d')
    # add a symbol column
    r['Symbol'] = ticker
    symbols.append(r)
# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
unknown= df[['Date', 'Adj Close', 'Symbol']]
df.head()
df_pivot=df.pivot('Date','Symbol','Adj Close')#.reset_index()
df_pivot.head()
# Calculate the percentage change (price returns) for each stock
returns = df_pivot.pct_change().dropna()
corr_df = returns.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DXY']: Exception("%ticker%: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']")
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['GLD-USD']: Exception("%ticker%: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', 'ytd', 'max']")
# <ipython-input-14-621efde3a4c1>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Adj Close')#.reset_index()

# %%
start = datetime(2022,9, 1)
symbols_list = [yahoo_id,'SPY', 'QQQ', 'ETH-USD', 'BTC-USD', 'TLT', 'DXY', 'GLD-USD']
#array to store prices
symbols=[]

#array to store prices
symbols=[]
for ticker in symbols_list:

    r = yf.download(tickers=ticker, period='200d')
    # add a symbol column
    r['Symbol'] = ticker
    symbols.append(r)
# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
unknown= df[['Date', 'Adj Close', 'Symbol']]
df.head()
df_pivot=df.pivot('Date','Symbol','Adj Close')#.reset_index()
df_pivot.head()
# Calculate the percentage change (price returns) for each stock

corr_df = returns.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DXY']: Exception("%ticker%: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']")
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['GLD-USD']: Exception("%ticker%: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', 'ytd', 'max']")
# <ipython-input-15-1a85edfbedff>:19: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot=df.pivot('Date','Symbol','Adj Close')#.reset_index()

# %%
# Plot the scatter plots
plt.subplot(122)
sns.set(style='ticks')
sns.pairplot(returns)
plt.suptitle('Correlation Scatter Plots', y=1.02)

plt.tight_layout()
plt.show()
# Save the plot as a JPEG image
plt.savefig('correlation_plot.jpg', dpi=300, format='jpeg')

# %% [markdown]
# # Crypto

# %% [markdown]
# Trade Management

# %%
#@title Fundamentals

import requests
import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()


response = requests.get("https://api.coingecko.com/api/v3/coins/{}".format(CoinGecko_id))
output = response.text
json_parsed = json.loads(output)


x = json_parsed['market_data']['fully_diluted_valuation']

def fdv_none_val(x):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if x is None :
    fully_diluted_valuation = 0
  else :
    fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']

  return fully_diluted_valuation



def zero_div(x,y):
  """
  handling 0 division error

  """
  try:
      return x/y
  except ZeroDivisionError:
      return 0
links = 'Complete list: '+str(json_parsed['links'])
chat_url = 'Chat: '+str(json_parsed['links']['chat_url'])
CoinGecko_Link =  'CoinGecko: '+ "https://www.coingecko.com/en/coins/" + CoinGecko_id
Twitters = 'Twitter: '+str('https://twitter.com/')+str(json_parsed['links']['twitter_screen_name'])
homepage = 'Homepage: '+str(json_parsed['links']['homepage'])
subreddit_url =  'Reddit: ' +str(json_parsed['links']['subreddit_url'])
pd.set_option('display.width', 10)

print('')
print('WEB Links')
print('')
print(homepage)
print(Twitters)
print(subreddit_url)
print(chat_url)
print(CoinGecko_Link)

print(links)

print('')
print('MARKET DATA')
print('')


market_cap = json_parsed['market_data']['market_cap']['usd']
circulating_supply = json_parsed['market_data']['circulating_supply']
# circulating_supply.astype(int)
current_price = json_parsed['market_data']['current_price']['usd']
# current_price.astype(int)
fdv_to_tvl_rati = json_parsed['market_data']['fdv_to_tvl_ratio']
# fdv_to_tvl_ratio.astype(int)


#fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']['usd']

# fully_diluted_valuation
total_supply = json_parsed['market_data']['total_supply']
max_supply = json_parsed['market_data']['max_supply']
mcap_to_tvl_ratio = json_parsed['market_data']['mcap_to_tvl_ratio']
total_supply = json_parsed['market_data']['total_supply']
#total_value_locked = json_parsed['market_data']['total_value_locked']['usd']
total_volume = json_parsed['market_data']['total_volume']['usd']

float_rotation_24h = zero_div(total_volume , market_cap)
circulating_cap = current_price * json_parsed['market_data']['circulating_supply']
total_cap = current_price * total_supply


def max_cap(current_price, max_supply):
  """
    Calculation of maximum capitalization
     Requiring current price and maximum supply
  """
  if max_supply is not None :
    max_cap = current_price * max_supply
  else :
    max_cap = 0
  return max_cap

max_cap = max_cap(current_price, max_supply)



def max_supply_expansion_multiple(circulating_supply, max_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if max_supply is None :
    max_supply_expansion_multiple = 0

  elif circulating_supply ==  0:
    max_supply_expansion_multiple == 0

  else :
    max_supply_expansion_multiple = max_supply  / circulating_supply

  return max_supply_expansion_multiple


max_supply_expansion_multiple = max_supply_expansion_multiple(circulating_supply, max_supply)

def total_supply_expansion_multiple(circulating_supply, total_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if total_supply is None :
    total_supply_expansion_multiple = 0

  elif circulating_supply == 0:
    total_supply_expansion_multiple == 0

  else :
    total_supply_expansion_multiple = total_supply  / circulating_supply

  return total_supply_expansion_multiple


"""
def market_cap_dilution_ratio(fully_diluted_valuation, market_cap):


  if fully_diluted_valuation or market_cap is None :
    market_cap_dilution_ratio == 0

  elif fully_diluted_valuation or market_cap is 0:
    market_cap_dilution_ratio == 0

  elif fully_diluted_valuation or market_cap is {}:
    market_cap_dilution_ratio == 0

  else :
    market_cap_dilution_ratio =  fully_diluted_valuation / market_cap

  return market_cap_dilution_ratio


market_cap_dilution_ratio = market_cap_dilution_ratio(fully_diluted_valuation, market_cap)
"""

print('')

circulating_versus_max = circulating_supply/total_supply
dict_custom = {}
#dict_custom['total_supply_expansion_multiple'] = total_supply_expansionWhere_multiple
dict_custom['max_supply_expansion_multiple'] = max_supply_expansion_multiple
dict_custom['float_rotation_24h'] = float_rotation_24h

dict_custom['circulating_versus_max'] = circulating_versus_max


print(dict_custom)

df_market = {}
df_market['market_cap'] = market_cap
#Final been up what is on the national emergency, informative or what basket is something the P is the spaciousness up to Sarah  ankedat1['circulating_supply'] = circulating_supply
df_market['current_price'] = current_price
# df_market['fdv_to_tvl_ratio'] = fdv_to_tvl_ratio#
#df_market['fully_diluted_valuation'] = fully_diluted_valuation
# ankedat1['max_supply'] = max_supply
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_supply'] = total_supply
#df_market['total_value_locked'] = total_value_locked
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_volume'] = total_volume


print(df_market)




print('          ')
print('PRICE ACTION')
price_change_percentage_7d = json_parsed['market_data']['price_change_percentage_7d']
price_change_percentage_14d = json_parsed['market_data']['price_change_percentage_14d']
price_change_percentage_30d = json_parsed['market_data']['price_change_percentage_30d']
price_change_percentage_60d = json_parsed['market_data']['price_change_percentage_60d']
price_change_percentage_200d = json_parsed['market_data']['price_change_percentage_200d']
price_change_percentage_1y = json_parsed['market_data']['price_change_percentage_1y']



dict_return = {}
dict_return['price_change_percentage_7d'] = price_change_percentage_7d
dict_return['price_change_percentage_14d'] = price_change_percentage_14d
dict_return['price_change_percentage_30d'] = price_change_percentage_30d
dict_return['price_change_percentage_60d'] = price_change_percentage_60d
dict_return['price_change_percentage_200d'] = price_change_percentage_200d
dict_return['price_change_percentage_1y'] = price_change_percentage_1y

print(dict_return)



category = json_parsed['categories']

print('')
print('CATEGORIES')
print(category)




description  = []
pd.set_option('display.width', 10)
pd.set_option("display.max_rows", None, "display.max_columns", None)
description = json_parsed['description']['en']

print('')
print('DESCRIPTION: ')
print(description)


links = json_parsed['links']

print('')
print('LIQUIDITY: ')
print('')

a = json_parsed['tickers']
data = pd.json_normalize(a,max_level=4)
df = pd.DataFrame(data)

df['pair'] = df['base'] + df['target']

df['market_and_volume'] = df['market.name']+ ' (' + df['volume'].round(1).astype(str)+')'
df['Exchanges'] = df.apply(lambda _: ', '.join(df['market_and_volume'] .tolist()), axis=1)
df['Exchanges'][1]

df
# Out:
# WEB Links
#
# Homepage: ['http://www.bitcoin.org', '', '']
# Twitter: https://twitter.com/bitcoin
# Reddit: https://www.reddit.com/r/Bitcoin/
# Chat: ['', '', '']
# CoinGecko: https://www.coingecko.com/en/coins/bitcoin
# Complete list: {'homepage': ['http://www.bitcoin.org', '', ''], 'whitepaper': 'https://bitcoin.org/bitcoin.pdf', 'blockchain_site': ['https://mempool.space/', 'https://blockchair.com/bitcoin/', 'https://btc.com/', 'https://btc.tokenview.io/', 'https://www.oklink.com/btc', 'https://3xpl.com/bitcoin', '', '', '', ''], 'official_forum_url': ['https://bitcointalk.org/', '', ''], 'chat_url': ['', '', ''], 'announcement_url': ['', ''], 'twitter_screen_name': 'bitcoin', 'facebook_username': 'bitcoins', 'bitcointalk_thread_identifier': None, 'telegram_channel_identifier': '', 'subreddit_url': 'https://www.reddit.com/r/Bitcoin/', 'repos_url': {'github': ['https://github.com/bitcoin/bitcoin', 'https://github.com/bitcoin/bips'], 'bitbucket': []}}
#
# MARKET DATA
#
#
# {'max_supply_expansion_multiple': 1.068839308204446, 'float_rotation_24h': 0.038091237499706415, 'circulating_versus_max': 0.9355943333333333}
# {'market_cap': 1323405869851, 'current_price': 67438, 'mcap_to_tvl_ratio': None, 'total_supply': 21000000.0, 'total_volume': 50410167297}
#
# PRICE ACTION
# {'price_change_percentage_7d': 7.22416, 'price_change_percentage_14d': 30.75353, 'price_change_percentage_30d': 56.20468, 'price_change_percentage_60d': 52.97684, 'price_change_percentage_200d': 158.74571, 'price_change_percentage_1y': 201.99409}
#
# CATEGORIES
# ['Proof of Work (PoW)', 'FTX Holdings', 'Layer 1 (L1)', 'Cryptocurrency']
#
# DESCRIPTION:
# Bitcoin is the first successful internet money based on peer-to-peer technology; whereby no central bank or authority is involved in the transaction and production of the Bitcoin currency. It was created by an anonymous individual/group under the name, Satoshi Nakamoto. The source code is available publicly as an open source project, anybody can look at it and be part of the developmental process.
#
# Bitcoin is changing the way we see money as we speak. The idea was to produce a means of exchange, independent of any central authority, that could be transferred electronically in a secure, verifiable and immutable way. It is a decentralized peer-to-peer internet currency making mobile payment easy, very low transaction fees, protects your identity, and it works anywhere all the time with no central authority and banks.
#
# Bitcoin is designed to have only 21 million BTC ever created, thus making it a deflationary currency. Bitcoin uses the <a href="https://www.coingecko.com/en?hashing_algorithm=SHA-256">SHA-256</a> hashing algorithm with an average transaction confirmation time of 10 minutes. Miners today are mining Bitcoin using ASIC chip dedicated to only mining Bitcoin, and the hash rate has shot up to peta hashes.
#
# Being the first successful online cryptography currency, Bitcoin has inspired other alternative currencies such as <a href="https://www.coingecko.com/en/coins/litecoin">Litecoin</a>, <a href="https://www.coingecko.com/en/coins/peercoin">Peercoin</a>, <a href="https://www.coingecko.com/en/coins/primecoin">Primecoin</a>, and so on.
#
# The cryptocurrency then took off with the innovation of the turing-complete smart contract by <a href="https://www.coingecko.com/en/coins/ethereum">Ethereum</a> which led to the development of other amazing projects such as <a href="https://www.coingecko.com/en/coins/eos">EOS</a>, <a href="https://www.coingecko.com/en/coins/tron">Tron</a>, and even crypto-collectibles such as <a href="https://www.coingecko.com/buzz/ethereum-still-king-dapps-cryptokitties-need-1-billion-on-eos">CryptoKitties</a>.
#
# LIQUIDITY:
#     base  \
# 0    BTC
# 1    BTC
# 2    BTC
# 3    BTC
# 4    BTC
# 5    BTC
# 6    BTC
# 7    BTC
# 8    BTC
# 9    BTC
# 10   BTC
# 11   BTC
# 12   BTC
# 13   BTC
# 14   BTC
# 15   BTC
# 16   BTC
# 17   BTC
# 18   BTC
# 19   BTC
# 20   ETH
# 21   BTC
# 22   BTC
# 23   ETH
# 24   BTC
# 25  WBTC
# 26   BTC
# 27   ETH
# 28   BTC
# 29   BTC
# 30   BTC
# 31   BTC
# 32   BTC
# 33   BTC
# 34   BTC
# 35   BTC
# 36   BTC
# 37   BTC
# 38   BTC
# 39   BTC
# 40   BTC
# 41   BTC
# 42   BTC
# 43   BTC
# 44   BTC
# 45   ETH
# 46   BTC
# 47   BTC
# 48   BTC
# 49   BTC
# 50   BTC
# 51   BTC
# 52   BTC
# 53   BTC
# 54   BTC
# 55   BTC
# 56   BTC
# 57   BTC
# 58   BTC
# 59   BTC
# 60   BTC
# 61   ETH
# 62   BTC
# 63   ETH
# 64   BTC
# 65   BTC
# 66   BTC
# 67   BTC
# 68   BTC
# 69   SOL
# 70   BTC
# 71   BTC
# 72   BTC
# 73   BTC
# 74   BTC
# 75   BTC
# 76   BTC
# 77   BTC
# 78   ETH
# 79   BTC
# 80   BTC
# 81   BTC
# 82   BTC
# 83   BTC
# 84   ETH
# 85   BTC
# 86   BTC
# 87   BTC
# 88   BTC
# 89   BTC
# 90   BTC
# 91   BTC
# 92   BTC
# 93   BTC
# 94   BTC
# 95   BTC
# 96   BTC
# 97   BTC
# 98   BTC
# 99   ETH
#
#    target  \
# 0    USDT
# 1    USDT
# 2    USDT
# 3    USDC
# 4    USDT
# 5     USD
# 6    USDT
# 7     USD
# 8    USDT
# 9    USDT
# 10   USDT
# 11    EUR
# 12   USDT
# 13   USDT
# 14   USDT
# 15    USD
# 16   USDT
# 17   USDT
# 18   USDT
# 19    EUR
# 20    BTC
# 21   USDT
# 22   USDT
# 23    BTC
# 24   USDT
# 25    BTC
# 26   USDT
# 27    BTC
# 28   USDT
# 29   USDT
# 30   USDT
# 31    USD
# 32   USDT
# 33   USDC
# 34   USDT
# 35   USDT
# 36   USDT
# 37    EUR
# 38    JPY
# 39    USD
# 40    EUR
# 41   USDC
# 42   USDT
# 43   USDC
# 44   USDT
# 45    BTC
# 46   USDC
# 47    USD
# 48   USDT
# 49   USDT
# 50   USDT
# 51   USDT
# 52   USDT
# 53   USDT
# 54    EUR
# 55   USDC
# 56   USDC
# 57   USDT
# 58   USDT
# 59   USDT
# 60   USDC
# 61    BTC
# 62   USDT
# 63    BTC
# 64    EUR
# 65    USD
# 66   USDC
# 67    JPY
# 68   USDT
# 69    BTC
# 70   USDT
# 71    GBP
# 72    JPY
# 73    EUR
# 74   USDC
# 75   USDT
# 76   USDT
# 77   USDT
# 78    XBT
# 79   TUSD
# 80    USD
# 81   USDT
# 82   USDC
# 83   USDC
# 84    BTC
# 85   USDT
# 86    JPY
# 87   USDC
# 88    CAD
# 89   USDT
# 90   USDT
# 91  XTUSD
# 92   USDT
# 93    EUR
# 94    USD
# 95   USDT
# 96    GBP
# 97   USDT
# 38  https://coin.z.com/jp/corp/information/btc-mar...
# 39     https://crypto.com/exchange/trade/spot/BTC_USD
# 40             https://pro.coinbase.com/trade/BTC-EUR
# 41          https://pro.kraken.com/app/trade/BTC-USDC
# 42               https://bingx.com/en-us/spot/BTCUSDT
# 43            https://www.okx.com/trade-spot/btc-usdc
# 44              https://c-patex.com/exchange/BTC/USDT
# 45        https://www.pionex.com/en/trade/ETH_BTC/Bot
# 46  https://www.binance.com/en/trade/BTC_USDC?ref=...
# 47           https://exchange.gemini.com/trade/BTCUSD
# 48  https://trading.bitfinex.com/t/BTC:UST?type=ex...
# 49                                               None
# 50              https://latoken.com/exchange/USDT-BTC
# 51           https://www.btse.com/en/trading/BTC-USDT
# 52         https://www.cointr.com/en-us/spot/BTC_USDT
# 53          https://pro.kraken.com/app/trade/BTC-USDT
# 54        https://account.bitvavo.com/markets/BTC-EUR
# 55                        https://fmfw.io/BTC-to-USDC
# 56               https://bingx.com/en-us/spot/BTCUSDC
# 57        https://www.fameex.com/en-US/trade/btc-usdt
# 58     https://www.deepcoin.com/en/Spot?currentId=BTC
# 59  https://ascendex.com/en/cashtrade-spottrading/...
# 60          https://www.bybit.com/trade/spot/BTC/USDC
# 61  https://trading.bitfinex.com/t/ETH:BTC?type=ex...
# 62            https://pro.coinbase.com/trade/BTC-USDT
# 63             https://www.okx.com/trade-spot/eth-btc
# 64    https://cryptology.com/app/next/trading/BTC_EUR
# 65          https://www.bitstamp.net/markets/btc/usd/
# 66               https://www.lbank.com/trade/btc_usdc
# 67                                               None
# 68           https://pro.bit2me.com/exchange/BTC-USDT
# 69                      https://hitbtc.com/SOL-to-BTC
# 70               https://www.xt.com/en/trade/btc_usdt
# 71           https://pro.kraken.com/app/trade/BTC-GBP
# 72               https://app.bitbank.cc/trade/btc_jpy
# 73  https://www.binance.com/en/trade/BTC_EUR?ref=3...
# 74                     https://hitbtc.com/BTC-to-USDC
# 75                https://whitebit.com/trade/BTC_USDT
# 76  https://exchange.pointpay.io/trade-classic/BTC...
# 77             https://nominex.io/en/markets/BTC/USDT
# 78           https://pro.kraken.com/app/trade/ETH-XBT
# 79  https://www.binance.com/en/trade/BTC_TUSD?ref=...
# 80                                               None
# 81             https://www.bydfi.com/en/spot/btc_usdt
# 82     https://www.digifinex.com/en-ww/trade/USDC/BTC
# 83  https://exchange.pointpay.io/trade-classic/BTC...
# 84              https://www.mexc.com/exchange/ETH_BTC
# 85      https://www.icrypex.com/en/trade/spot/BTCUSDT
# 86             https://bitflyer.com/en-jp/ex/simpleex
# 87               https://www.xt.com/en/trade/btc_usdc
# 88           https://pro.kraken.com/app/trade/BTC-CAD
# 89          https://www.bitvenus.me/exchange/BTC/USDT
# 90  https://dex-trade.com/spot/trading/BTCUSDT?int...
# 91              https://www.xt.com/en/trade/btc_xtusd
# 92   https://www.bitmart.com/trade/en?symbol=BTC_USDT
# 93          https://www.bitstamp.net/markets/btc/eur/
# 94         https://pro.hashkey.com/en-US/spot/BTC_USD
# 95           https://www.coinstore.com/#/spot/BTCUSDT
# 96             https://pro.coinbase.com/trade/BTC-GBP
# 97            https://bitexlive.com/exchange/USDT-BTC
# 98                 https://whitebit.com/trade/BTC_USD
# 99          https://www.bitstamp.net/markets/eth/btc/
#
#    token_info_url  \
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
# 32           None
# 33           None
# 34           None
# 35           None
# 36           None
# 37           None
# 38           None
# 39           None
# 40           None
# 41           None
# 42           None
# 43           None
# 44           None
# 45           None
# 46           None
# 47           None
# 48           None
# 49           None
# 50           None
# 51           None
# 52           None
# 53           None
# 54           None
# 55           None
# 56           None
# 57           None
# 58           None
# 59           None
# 60           None
# 61           None
# 62           None
# 63           None
# 64           None
# 65           None
# 66           None
# 67           None
# 68           None
# 69           None
# 70           None
# 71           None
# 72           None
# 73           None
# 74           None
# 75           None
# 76           None
# 77           None
# 78           None
# 79           None
# 80           None
# 81           None
# 82           None
# 83           None
# 84           None
# 85           None
# 86           None
# 87           None
# 88           None
# 89           None
# 90           None
# 91           None
# 92           None
# 93           None
# 94           None
# 95           None
# 96           None
# 97           None
# 98           None
# 99           None
#
#             coin_id  \
# 0           bitcoin
# 1           bitcoin
# 2           bitcoin
# 3           bitcoin
# 4           bitcoin
# 5           bitcoin
# 6           bitcoin
# 7           bitcoin
# 8           bitcoin
# 9           bitcoin
# 10          bitcoin
# 11          bitcoin
# 12          bitcoin
# 13          bitcoin
# 14          bitcoin
# 15          bitcoin
# 16          bitcoin
# 17          bitcoin
# 18          bitcoin
# 19          bitcoin
# 20         ethereum
# 21          bitcoin
# 22          bitcoin
# 23         ethereum
# 24          bitcoin
# 25  wrapped-bitcoin
# 26          bitcoin
# 27         ethereum
# 28          bitcoin
# 29          bitcoin
# 30          bitcoin
# 31          bitcoin
# 32          bitcoin
# 33          bitcoin
# 34          bitcoin
# 35          bitcoin
# 36          bitcoin
# 37          bitcoin
# 38          bitcoin
# 39          bitcoin
# 40          bitcoin
# 41          bitcoin
# 42          bitcoin
# 43          bitcoin
# 44          bitcoin
# 45         ethereum
# 46          bitcoin
# 47          bitcoin
# 48          bitcoin
# 49          bitcoin
# 50          bitcoin
# 51          bitcoin
# 52          bitcoin
# 53          bitcoin
# 54          bitcoin
# 55          bitcoin
# 56          bitcoin
# 57          bitcoin
# 58          bitcoin
# 59          bitcoin
# 60          bitcoin
# 61         ethereum
# 62          bitcoin
# 63         ethereum
# 64          bitcoin
# 65          bitcoin
# 66          bitcoin
# 67          bitcoin
# 68          bitcoin
# 69           solana
# 70          bitcoin
# 71          bitcoin
# 72          bitcoin
# 73          bitcoin
# 74          bitcoin
# 75          bitcoin
# 76          bitcoin
# 77          bitcoin
# 78         ethereum
# 79          bitcoin
# 80          bitcoin
# 81          bitcoin
# 82          bitcoin
# 83          bitcoin
# 84         ethereum
# 85          bitcoin
# 86          bitcoin
# 87          bitcoin
# 88          bitcoin
# 89          bitcoin
# 90          bitcoin
# 91          bitcoin
# 92          bitcoin
# 93          bitcoin
# 94          bitcoin
# 95          bitcoin
# 96          bitcoin
# 97          bitcoin
# 98          bitcoin
# 99         ethereum
#
#    target_coin_id  \
# 0          tether
# 1          tether
# 2          tether
# 3        usd-coin
# 4          tether
# 5             NaN
# 6          tether
# 7             NaN
# 8          tether
# 9          tether
# 10         tether
# 11            NaN
# 12         tether
# 13         tether
# 14         tether
# 15            NaN
# 16         tether
# 17         tether
# 18         tether
# 19            NaN
# 20        bitcoin
# 21         tether
# 22         tether
# 23        bitcoin
# 24         tether
# 25        bitcoin
# 26         tether
# 27        bitcoin
# 28         tether
# 29         tether
# 30         tether
# 31            NaN
# 32         tether
# 33       usd-coin
# 34         tether
# 35         tether
# 36         tether
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41       usd-coin
# 42         tether
# 43       usd-coin
# 44         tether
# 45        bitcoin
# 46       usd-coin
# 47            NaN
# 48         tether
# 49         tether
# 50         tether
# 51         tether
# 52         tether
# 53         tether
# 54            NaN
# 55       usd-coin
# 56       usd-coin
# 57         tether
# 58         tether
# 59         tether
# 60       usd-coin
# 61        bitcoin
# 62         tether
# 63        bitcoin
# 64            NaN
# 65            NaN
# 66       usd-coin
# 67            NaN
# 68         tether
# 69        bitcoin
# 70         tether
# 71            NaN
# 72            NaN
# 73            NaN
# 74       usd-coin
# 75         tether
# 76         tether
# 77         tether
# 78        bitcoin
# 79       true-usd
# 80            NaN
# 81         tether
# 82       usd-coin
# 83       usd-coin
# 84        bitcoin
# 85         tether
# 86            NaN
# 87       usd-coin
# 88            NaN
# 89         tether
# 90         tether
# 91          xtusd
# 92         tether
# 93            NaN
# 94            NaN
# 95         tether
# 96            NaN
# 97         tether
# 98            NaN
# 99        bitcoin
#
#             market.name  \
# 0               OrangeX
# 1               Binance
# 2                Tapbit
# 3                Tapbit
# 4        Hotcoin Global
# 5                Kraken
# 6                  WEEX
# 7     Coinbase Exchange
# 8                  MEXC
# 9               Gate.io
# 10                Bybit
# 11               Kraken
# 12                  OKX
# 13                  HTX
# 14               HitBTC
# 15             Bitfinex
# 16              FMFW.io
# 17               Pionex
# 18               Bitrue
# 19               Bit2Me
# 20              FMFW.io
# 21               Bitget
# 22               Toobit
# 23               HitBTC
# 24                LBank
# 25              Binance
# 26                Dcoin
# 27              Binance
# 28               KuCoin
# 29               BigONE
# 30             Biconomy
# 31                 BTSE
# 32  Crypto.com Exchange
# 33             Biconomy
# 34  Bitcointry Exchange
# 35                WOO X
# 36            DigiFinex
# 37             Bitfinex
# 38            GMO Japan
# 39  Crypto.com Exchange
# 40    Coinbase Exchange
# 41               Kraken
# 42                BingX
# 43                  OKX
# 44              C-Patex
# 45               Pionex
# 46              Binance
# 47               Gemini
# 48             Bitfinex
# 49                  P2B
# 50              LATOKEN
# 51                 BTSE
# 52           CoinTR Pro
# 53               Kraken
# 54              Bitvavo
# 55              FMFW.io
# 56                BingX
# 57               FameEX
# 58             Deepcoin
# 59    AscendEX (BitMax)
# 60                Bybit
# 61             Bitfinex
# 62    Coinbase Exchange
# 63                  OKX
# 64           Cryptology
# 65             Bitstamp
# 66                LBank
# 67            Coincheck
# 68               Bit2Me
# 69               HitBTC
# 70               XT.COM
# 71               Kraken
# 72              Bitbank
# 73              Binance
# 74               HitBTC
# 75             WhiteBIT
# 76             PointPay
# 77              Nominex
# 78               Kraken
# 79              Binance
# 80                  P2B
# 81                BYDFi
# 82            DigiFinex
# 83             PointPay
# 84                 MEXC
# 85              Icrypex
# 86             bitFlyer
# 87               XT.COM
# 88               Kraken
# 89             BitVenus
# 90            Dex-Trade
# 91               XT.COM
# 92              BitMart
# 93             Bitstamp
# 94     HashKey Exchange
# 95            Coinstore
# 96    Coinbase Exchange
# 97            Bitexlive
# 98             WhiteBIT
# 99             Bitstamp
#
#       market.identifier  \
# 0               orangex
# 1               binance
# 2                tapbit
# 3                tapbit
# 4        hotcoin_global
# 5                kraken
# 6                  weex
# 7                  gdax
# 8                   mxc
# 9                  gate
# 10           bybit_spot
# 11               kraken
# 12                 okex
# 13                huobi
# 14               hitbtc
# 15             bitfinex
# 16          bitcoin_com
# 17               pionex
# 18               bitrue
# 19               bit2me
# 20          bitcoin_com
# 21               bitget
# 22               toobit
# 23               hitbtc
# 24                lbank
# 25              binance
# 26                dcoin
# 27              binance
# 28               kucoin
# 29               bigone
# 30             biconomy
# 31                 btse
# 32           crypto_com
# 33             biconomy
# 34  bitcointry_exchange
# 35             wootrade
# 36            digifinex
# 37             bitfinex
# 38            gmo_japan
# 39           crypto_com
# 40                 gdax
# 41               kraken
# 42                bingx
# 43                 okex
# 44              c_patex
# 45               pionex
# 46              binance
# 47               gemini
# 48             bitfinex
# 49               p2pb2b
# 50              latoken
# 51                 btse
# 52               cointr
# 53               kraken
# 54              bitvavo
# 55          bitcoin_com
# 56                bingx
# 57               fameex
# 58             deepcoin
# 59               bitmax
# 60           bybit_spot
# 61             bitfinex
# 62                 gdax
# 63                 okex
# 64           cryptology
# 65             bitstamp
# 66                lbank
# 67            coincheck
# 68               bit2me
# 69               hitbtc
# 70                   xt
# 71               kraken
# 72              bitbank
# 73              binance
# 74               hitbtc
# 75             whitebit
# 76             pointpay
# 77              nominex
# 78               kraken
# 79              binance
# 80               p2pb2b
# 81                bydfi
# 82            digifinex
# 83             pointpay
# 84                  mxc
# 85              icrypex
# 86             bitflyer
# 87                   xt
# 88               kraken
# 89        bitvenus_spot
# 90             dextrade
# 91                   xt
# 92              bitmart
# 93             bitstamp
# 94     hashkey_exchange
# 95            coinstore
# 96                 gdax
# 97            bitexlive
# 98             whitebit
# 99             bitstamp
#
#     market.has_trading_incentive  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# 5                          False
# 6                          False
# 7                          False
# 8                          False
# 9                          False
# 10                         False
# 11                         False
# 12                         False
# 13                         False
# 14                         False
# 15                         False
# 16                         False
# 17                         False
# 18                         False
# 19                         False
# 20                         False
# 21                         False
# 22                         False
# 23                         False
# 24                         False
# 25                         False
# 26                         False
# 27                         False
# 28                         False
# 29                         False
# 30                         False
# 31                         False
# 32                         False
# 33                         False
# 34                         False
# 35                         False
# ...
# 20              3030.000
# 21            109483.000
# 22            201192.000
# 23              3049.000
# 24            172607.000
# 25              7163.000
# 26              8894.000
# 27             45639.000
# 28            136170.000
# 29             95329.000
# 30             81605.000
# 31             74903.000
# 32            124114.000
# 33             25834.000
# 34               320.446
# 35              7462.000
# 36            268053.000
# 37               394.322
# 38              5074.000
# 39             96213.000
# 40             11008.000
# 41              2832.000
# 42            171372.000
# 43             52165.000
# 44             12519.000
# 45              7906.000
# 46             21912.000
# 47             15569.000
# 48              7157.000
# 49            188965.000
# 50             95081.000
# 51             50513.000
# 52            134128.000
# 53              5672.000
# 54             17561.000
# 55              8736.000
# 56              8683.000
# 57             32840.000
# 58            206521.000
# 59             18553.000
# 60            117523.000
# 61              2444.000
# 62             16977.000
# 63             18709.000
# 64              2002.000
# 65             58700.000
# 66             91925.000
# 67             32397.000
# 68              5533.000
# 69               302.098
# 70            102678.000
# 71              1834.000
# 72              5190.000
# 73              8655.000
# 74              8558.000
# 75            275269.000
# 76             15249.000
# 77               693.617
# 78              3071.000
# 79              6075.000
# 80            185240.000
# 81             48359.000
# 82             11556.000
# 83              2121.000
# 84               188.000
# 85              9162.000
# 86             28741.000
# 87              3317.000
# 88               536.523
# 89            146730.000
# 90             10256.000
# 91               669.505
# 92            334540.000
# 93              9883.000
# 94              3545.000
# 95             29850.000
# 96              5298.000
# 97              1942.000
# 98              1239.000
# 99               935.402
#
#     converted_volume.usd  \
# 0             3616507398
# 1             3678977020
# 2              310226650
# 3              172751579
# 4              802815359
# 5              220656673
# 6               77963081
# 7             1499508191
# 8              471606300
# 9              133201841
# 10            1266791505
# 11              79878667
# 12             855798323
# 13             128533202
# 14             114214776
# 15             128299861
# 16             115865485
# 17             855831713
# 18            1711640091
# 19              78043584
# 20              11646639
# 21             420384169
# 22             772518479
# 23              11722180
# 24             663529294
# 25              27525075
# 26              34163650
# 27             175384991
# 28             523067954
# 29             365548615
# 30             313702929
# 31             287225461
# 32             476562969
# 33              99236806
# 34               1230197
# 35              28683600
# 36            1029244809
# 37               1514082
# 38              19467214
# 39             369430859
# 40              42268556
# 41              10875949
# 42             658781562
# 43             200298137
# 44              48029148
# 45              30335634
# 46              84134610
# 47              59780674
# 48              27479263
# 49             724982361
# 50             365505339
# 51             193699027
# 52             515609019
# 53              21779584
# 54              67341368
# 55              33582096
# 56              33378650
# 57             126094572
# 58             793900585
# 59              71236835
# 60             451775867
# 61               9385824
# 62              65186320
# 63              71918517
# 64               7689926
# 65             225390536
# 66             353372254
# 67             124295362
# 68              21246437
# 69               1160450
# 70             393731822
# 71               7049646
# 72              19913835
# 73              33231632
# 74              32898353
# 75            1056270385
# 76              58575727
# 77               2661132
# 78              11804608
# 79              23344303
# 80             710691235
# 81             185564133
# 82              44373276
# 83               8139011
# 84                722703
# 85              35162664
# 86             110189240
# 87              12721088
# 88               2062478
# 89             563399754
# 90              39327236
# 91               2567298
# 92            1286022553
# 93              37948953
# 94              13610496
# 95             114747039
# 96              20352313
# 97               7465811
# 98               4755760
# 99               3588765
#
#         pair  \
# 0    BTCUSDT
# 1    BTCUSDT
# 2    BTCUSDT
# 3    BTCUSDC
# 4    BTCUSDT
# 5     BTCUSD
# 6    BTCUSDT
# 7     BTCUSD
# 8    BTCUSDT
# 9    BTCUSDT
# 10   BTCUSDT
# 11    BTCEUR
# 12   BTCUSDT
# 13   BTCUSDT
# 14   BTCUSDT
# 15    BTCUSD
# 16   BTCUSDT
# 17   BTCUSDT
# 18   BTCUSDT
# 19    BTCEUR
# 20    ETHBTC
# 21   BTCUSDT
# 22   BTCUSDT
# 23    ETHBTC
# 24   BTCUSDT
# 25   WBTCBTC
# 26   BTCUSDT
# 27    ETHBTC
# 28   BTCUSDT
# 29   BTCUSDT
# 30   BTCUSDT
# 31    BTCUSD
# 32   BTCUSDT
# 33   BTCUSDC
# 34   BTCUSDT
# 35   BTCUSDT
# 36   BTCUSDT
# 37    BTCEUR
# 38    BTCJPY
# 39    BTCUSD
# 40    BTCEUR
# 41   BTCUSDC
# 42   BTCUSDT
# 43   BTCUSDC
# 44   BTCUSDT
# 45    ETHBTC
# 46   BTCUSDC
# 47    BTCUSD
# 48   BTCUSDT
# 49   BTCUSDT
# 50   BTCUSDT
# 51   BTCUSDT
# 52   BTCUSDT
# 53   BTCUSDT
# 54    BTCEUR
# 55   BTCUSDC
# 56   BTCUSDC
# 57   BTCUSDT
# 58   BTCUSDT
# 59   BTCUSDT
# 60   BTCUSDC
# 61    ETHBTC
# 62   BTCUSDT
# 63    ETHBTC
# 64    BTCEUR
# 65    BTCUSD
# 66   BTCUSDC
# 67    BTCJPY
# 68   BTCUSDT
# 69    SOLBTC
# 70   BTCUSDT
# 71    BTCGBP
# 72    BTCJPY
# 73    BTCEUR
# 74   BTCUSDC
# 75   BTCUSDT
# 76   BTCUSDT
# 77   BTCUSDT
# 78    ETHXBT
# 79   BTCTUSD
# 80    BTCUSD
# 81   BTCUSDT
# 82   BTCUSDC
# 83   BTCUSDC
# 84    ETHBTC
# 85   BTCUSDT
# 86    BTCJPY
# 87   BTCUSDC
# 88    BTCCAD
# 89   BTCUSDT
# 90   BTCUSDT
# 91  BTCXTUSD
# 92   BTCUSDT
# 93    BTCEUR
# 94    BTCUSD
# 95   BTCUSDT
# 96    BTCGBP
# 97   BTCUSDT
# 98    BTCUSD
# 99    ETHBTC
#
#                market_and_volume  \
# 0              OrangeX (54254.3)
# 1              Binance (55130.6)
# 2                Tapbit (4650.7)
# 3                Tapbit (2588.9)
# 4       Hotcoin Global (11908.4)
# 5                Kraken (3271.3)
# 6                  WEEX (1154.5)
# 7    Coinbase Exchange (22239.6)
# 8                  MEXC (6993.2)
# 9               Gate.io (1994.7)
# 10               Bybit (18989.0)
# 11               Kraken (1184.1)
# 12                 OKX (12825.3)
# 13                  HTX (1925.3)
# 14               HitBTC (1714.0)
# 15             Bitfinex (1905.5)
# 16              FMFW.io (1720.4)
# 17              Pionex (12821.4)
# 18              Bitrue (25390.4)
# 19               Bit2Me (1160.4)
# 20              FMFW.io (3033.8)
# 21               Bitget (6301.1)
# 22              Toobit (11577.5)
# 23               HitBTC (3033.8)
# 24                LBank (9843.0)
# 25               Binance (408.0)
# 26                 Dcoin (507.0)
# 27             Binance (45441.6)
# 28               KuCoin (7759.1)
# 29               BigONE (5429.5)
# 30             Biconomy (4704.3)
# 31                 BTSE (4263.5)
# 32  Crypto.com Exchange (7067.1)
# 33             Biconomy (1488.1)
# 34    Bitcointry Exchange (18.4)
# 35                 WOO X (425.7)
# 36           DigiFinex (15272.3)
# 37               Bitfinex (22.4)
# 38             GMO Japan (288.9)
# 39  Crypto.com Exchange (5469.6)
# 40     Coinbase Exchange (626.3)
# 41                Kraken (161.1)
# 42                BingX (9874.4)
# 43                  OKX (2997.0)
# 44               C-Patex (711.9)
# 45               Pionex (7865.3)
# 46              Binance (1257.3)
# 47                Gemini (886.0)
# 48              Bitfinex (407.6)
# 49                 P2B (10750.2)
# 50              LATOKEN (5427.2)
# 51                 BTSE (2877.8)
# 52           CoinTR Pro (7738.4)
# 53                Kraken (322.9)
# 54               Bitvavo (999.5)
# 55               FMFW.io (497.6)
# 56                 BingX (499.6)
# 57               FameEX (1887.8)
# 58            Deepcoin (12206.3)
# 59    AscendEX (BitMax) (1057.1)
# 60                Bybit (6763.7)
# 61             Bitfinex (2443.7)
# 62     Coinbase Exchange (965.3)
# 63                 OKX (18616.7)
# 64            Cryptology (113.9)
# 65             Bitstamp (3337.0)
# 66                LBank (5229.5)
# 67            Coincheck (1843.5)
# 68                Bit2Me (316.5)
# 69               HitBTC (8192.6)
# 70               XT.COM (5904.8)
# 71                Kraken (104.5)
# 72               Bitbank (295.5)
# 73               Binance (495.8)
# 74                HitBTC (492.3)
# 75            WhiteBIT (15693.7)
# 76              PointPay (879.0)
# 77                Nominex (39.5)
# 78               Kraken (3076.0)
# 79               Binance (349.9)
# 80                 P2B (10547.8)
# 81                BYDFi (2755.4)
# 82             DigiFinex (657.0)
# 83              PointPay (121.9)
# 84                  MEXC (188.2)
# 85               Icrypex (522.4)
# 86             bitFlyer (1641.1)
# 87                XT.COM (190.4)
# 88                 Kraken (30.6)
# 89             BitVenus (8456.0)
# 90             Dex-Trade (584.2)
# 91                 XT.COM (38.5)
# 92             BitMart (19075.6)
# 93              Bitstamp (562.0)
# 94      HashKey Exchange (205.0)
# 95            Coinstore (1722.1)
# 96     Coinbase Exchange (301.6)
# 97             Bitexlive (110.9)
# 98               WhiteBIT (70.2)
# 99              Bitstamp (935.9)
#
#                                             Exchanges
# 0   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 1   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 2   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 3   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 4   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 5   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 6   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 7   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 8   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 9   OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 10  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 11  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 12  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 13  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 14  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 15  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 16  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 17  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 18  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 19  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 20  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 21  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 22  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 23  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 24  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 25  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 26  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 27  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 28  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 29  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 30  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 31  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 32  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 33  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 34  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 35  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 36  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 37  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 38  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 39  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 40  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 41  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 42  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 43  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 44  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 45  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 46  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 47  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 48  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 49  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 50  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 51  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 52  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 53  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 54  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 55  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 56  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 57  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 58  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 59  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 60  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 61  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 62  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 63  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 64  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 65  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 66  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 67  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 68  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 69  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 70  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 71  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 72  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 73  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 74  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 75  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 76  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 77  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 78  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 79  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 80  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 81  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 82  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 83  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 84  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 85  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 86  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 87  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 88  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 89  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 90  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 91  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 92  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 93  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 94  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 95  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 96  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 97  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 98  OrangeX (54254.3), Binance (55130.6), Tapbit (...
# 99  OrangeX (54254.3), Binance (55130.6), Tapbit (...

# %%
#@title Charts


import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()

"""
1 - 2 days: 30 minutes
3 - 30 days: 4 hours
31 days and beyond: 4 days
"""
#chart  1
a = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 'max' )
df  = pd.DataFrame(data=a, columns = ['Date','Open','High', 'Low', 'Close'])
df['datetime'] = pd.to_datetime(df['Date'], unit='ms')
fig2 = go.Figure(data=[go.Candlestick(x=df['datetime'],open=df['Open'], high=df['High'],low=df['Low'], close=df['Close'])])
fig2.show()

#chart   2
b = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 180 )
df2  = pd.DataFrame(data=b, columns = ['Date','Open','High', 'Low', 'Close'])
df2['datetime'] = pd.to_datetime(df2['Date'], unit='ms')
fig3 = go.Figure(data=[go.Candlestick(x=df2['datetime'],open=df2['Open'], high=df2['High'],low=df2['Low'], close=df2['Close'])])
fig3.show()

#chart   3
b = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 30 )
df2  = pd.DataFrame(data=b, columns = ['Date','Open','High', 'Low', 'Close'])
df2['datetime'] = pd.to_datetime(df2['Date'], unit='ms')
fig3 = go.Figure(data=[go.Candlestick(x=df2['datetime'],open=df2['Open'], high=df2['High'],low=df2['Low'], close=df2['Close'])])
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b08582d0-53d9-45dc-b052-48608ccf8170" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b08582d0-53d9-45dc-b052-48608ccf8170")) {                    Plotly.newPlot(                        "b08582d0-53d9-45dc-b052-48608ccf8170",                        [{"close":[135.3,91.01,106.4,113.01,114.16,120.5,125.75,128.99,127.98,121.16,119.0,105.99,98.4,106.55,107.25,103.39,95.39,90.8,68.08,85.75,94.0,88.79,91.7,94.13,110.34,103.7,106.75,103.77,111.87,118.78,120.0,125.67,137.76,137.51,123.73,131.65,129.95,130.23,126.73,131.84,131.65,123.07,128.38,130.27,143.89,170.51,206.78,189.83,203.88,212.45,295.63,340.55,424.16,614.4,819.31,914.13,1127.45,1078.64,811.98,887.08,854.62,677.84,645.75,734.27,755.16,
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     257                 raise Unauthorized(resp)
#     258             if resp.status_code == 403:
# --> 259                 raise Forbidden(resp)
#     260             if resp.status_code == 404:
#     261                 raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 453 - You currently have access to a subset of Twitter API v2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.twitter.com/en/portal/product

# %% [markdown]
# # Stocks

# %%
#@title Chart
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go


ticker=yahoo_id

data = yf.download(tickers=ticker, period='200d')
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#@title Seasonality

# %% [markdown]
# #Back test

# %%
tickr = yf.Ticker(ticker)

# %%
# get all stock info
tickr.info
# Out:
# {'address1': '1166 Alberni Street',
#  'address2': 'Suite 1606',
#  'city': 'Vancouver',
#  'state': 'BC',
#  'zip': 'V6E 3Z3',
#  'country': 'Canada',
#  'website': 'https://tribetech.com',
#  'industry': 'Real Estate Services',
#  'industryKey': 'real-estate-services',
#  'industryDisp': 'Real Estate Services',
#  'sector': 'Real Estate',
#  'sectorKey': 'real-estate',
#  'sectorDisp': 'Real Estate',
#  'longBusinessSummary': 'Tribe Property Technologies Inc. provides technology-enabled property management services. It operates through Software and Services, and Software Licensing Fees segments. It engages in the technology-enabled management of condominium and residential communities through its community-living software platform, and related services to property developers, condominium and residential communities, and owners and residents through its deficiency management software. The company was formerly known as Cherry Street Capital Inc. and changed its name to Tribe Property Technologies Inc. in March 2021. The company was formerly known as Cherry Street Capital Inc. and changed its name to Tribe Property Technologies Inc. in March 2021. Tribe Property Technologies Inc. is headquartered in Vancouver, Canada.',
#  'fullTimeEmployees': 283,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Joseph  Nakhla',
#    'age': 49,
#    'title': 'CEO & Director',
#    'yearBorn': 1974,
#    'fiscalYear': 2022,
#    'totalPay': 299232,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Fiona  Therrien',
#    'title': 'Executive Vice President of Management Services',
#    'fiscalYear': 2022,
#    'totalPay': 219120,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Angelo  Bartolini',
#    'title': 'President & CFO',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Dan  Feeny',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Shobana  Williams',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jenn  Laidlaw',
#    'title': 'Vice President of Marketing & Communications',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Lawrence  Liu',
#    'title': 'Vice President of Sales & Partnerships',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Randall Scott Ullrich',
#    'title': 'Executive Vice President',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Danielle  Fiddick',
#    'title': 'Director of Strategic Initiatives & Corporate Secretary',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 0.48,
#  'open': 0.48,
#  'dayLow': 0.48,
#  'dayHigh': 0.48,
#  'regularMarketPreviousClose': 0.48,
#  'regularMarketOpen': 0.48,
#  'regularMarketDayLow': 0.48,
#  'regularMarketDayHigh': 0.48,
#  'beta': 1.611,
#  'forwardPE': -2.8235292,
#  'volume': 840,
#  'regularMarketVolume': 840,
#  'averageVolume': 10204,
#  'averageVolume10days': 11533,
#  'averageDailyVolume10Day': 11533,
#  'bid': 0.49,
#  'ask': 0.5,
#  'marketCap': 10179600,
#  'fiftyTwoWeekLow': 0.45,
#  'fiftyTwoWeekHigh': 1.65,
#  'priceToSalesTrailing12Months': 0.5350213,
#  'fiftyDayAverage': 0.5803,
#  'twoHundredDayAverage': 0.805075,
#  'currency': 'CAD',
#  'enterpriseValue': 15100852,
#  'profitMargins': -0.52465,
#  'floatShares': 6914499,
#  'sharesOutstanding': 21207500,
#  'sharesShort': 870,
#  'sharesShortPriorMonth': 685,
#  'sharesShortPreviousMonthDate': 1706659200,
#  'dateShortInterest': 1709164800,
#  'heldPercentInsiders': 0.65248,
#  'heldPercentInstitutions': 0.077470005,
#  'shortRatio': 0.16,
#  'impliedSharesOutstanding': 21207500,
#  'bookValue': 0.499,
#  'priceToBook': 0.9619238,
#  'lastFiscalYearEnd': 1672444800,
#  'nextFiscalYearEnd': 1703980800,
#  'mostRecentQuarter': 1696032000,
#  'netIncomeToCommon': -9982220,
#  'trailingEps': -0.47,
#  'forwardEps': -0.17,
#  'enterpriseToRevenue': 0.794,
#  'enterpriseToEbitda': -1.627,
#  '52WeekChange': -0.6903226,
#  'SandP52WeekChange': 0.30279303,
#  'exchange': 'VAN',
#  'quoteType': 'EQUITY',
#  'symbol': 'TRBE.V',
#  'underlyingSymbol': 'TRBE.V',
#  'shortName': 'TRIBE PROPERTY TECHNOLOGIES INC',
#  'longName': 'Tribe Property Technologies Inc.',
#  'firstTradeDateEpochUtc': 1616679000,
#  'timeZoneFullName': 'America/Toronto',
#  'timeZoneShortName': 'EST',
#  'uuid': '006cb54f-e986-3cea-a2a6-133f7ad91375',
#  'messageBoardId': 'finmb_573873100',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 0.48,
#  'targetHighPrice': 3.25,
#  'targetLowPrice': 2.0,
#  'targetMeanPrice': 2.63,
#  'targetMedianPrice': 2.63,
#  'recommendationMean': 1.5,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 2,
#  'totalCash': 1589060,
#  'totalCashPerShare': 0.075,
#  'ebitda': -9280935,
#  'totalDebt': 6510304,
#  'quickRatio': 0.696,
#  'currentRatio': 0.753,
#  'totalRevenue': 19026532,
#  'debtToEquity': 61.525,
#  'revenuePerShare': 0.897,
#  'returnOnAssets': -0.24159999,
#  'returnOnEquity': -0.64472,
#  'freeCashflow': -5205348,
#  'operatingCashflow': -8405050,
#  'revenueGrowth': 0.059,
#  'grossMargins': 0.39234,
#  'ebitdaMargins': -0.48779,
#  'operatingMargins': -0.40453,
#  'financialCurrency': 'CAD',
#  'trailingPegRatio': None}

# %%
# show holders
tickr.major_holders
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py:557: RuntimeWarning:
#
# invalid value encountered in cast
# Breakdown                       Value
# insidersPercentHeld           0.65248
# institutionsPercentHeld       0.07747
# institutionsFloatPercentHeld  0.22291
# institutionsCount             2.00000

# %%
tickr.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
tickr.recommendations
# Out:
#   period  \
# 0     0m
# 1    -1m
# 2    -2m
# 3    -3m
#
#    strongBuy  \
# 0          0
# 1          0
# 2          0
# 3          0
#
#    buy  \
# 0    0
# 1    0
# 2    0
# 3    0
#
#    hold  \
# 0     0
# 1     0
# 2     0
# 3     0
#
#    sell  \
# 0     0
# 1     0
# 2     0
# 3     0
#
#    strongSell
# 0           0
# 1           0
# 2           0
# 3           0

# %%
tickr.calendar
# Out:
# {'Earnings Date': [],
#  'Earnings High': None,
#  'Earnings Low': None,
#  'Earnings Average': None,
#  'Revenue High': 4900000,
#  'Revenue Low': 4840000,
#  'Revenue Average': 4870000}

# %%
tickr.earnings_dates
# Out:
#                            EPS Estimate  \
# Earnings Date
# 2023-11-29 16:00:00-05:00         -0.08
# 2023-08-29 21:00:00-04:00         -0.10
# 2023-05-30 17:00:00-04:00         -0.12
# 2023-05-01 16:00:00-04:00         -0.14
# 2022-11-29 16:00:00-05:00         -0.14
# 2022-08-29 18:00:00-04:00         -0.09
# 2022-05-30 17:00:00-04:00         -0.10
# 2022-05-02 17:00:00-04:00         -0.14
# 2021-11-23 19:00:00-05:00           NaN
#
#                            Reported EPS  \
# Earnings Date
# 2023-11-29 16:00:00-05:00         -0.10
# 2023-08-29 21:00:00-04:00           NaN
# 2023-05-30 17:00:00-04:00           NaN
# 2023-05-01 16:00:00-04:00         -0.13
# 2022-11-29 16:00:00-05:00         -0.13
# 2022-08-29 18:00:00-04:00         -0.14
# 2022-05-30 17:00:00-04:00         -0.10
# 2022-05-02 17:00:00-04:00         -0.07
# 2021-11-23 19:00:00-05:00           NaN
#
#                            Surprise(%)
# Earnings Date
# 2023-11-29 16:00:00-05:00      -0.2500
# 2023-08-29 21:00:00-04:00          NaN
# 2023-05-30 17:00:00-04:00          NaN
# 2023-05-01 16:00:00-04:00       0.0714
# 2022-11-29 16:00:00-05:00       0.0714
# 2022-08-29 18:00:00-04:00      -0.5556
# 2022-05-30 17:00:00-04:00      -0.0100
# 2022-05-02 17:00:00-04:00       0.5000
# 2021-11-23 19:00:00-05:00          NaN

# %%
tickr.news
# Out:
# [{'uuid': '77a6555a-0a6b-4df3-b1c2-ed1f45922b0a',
#   'title': 'The Backbone One mobile game controller is 30 percent off right now',
#   'publisher': 'Engadget',
#   'link': 'https://finance.yahoo.com/m/77a6555a-0a6b-4df3-b1c2-ed1f45922b0a/the-backbone-one-mobile-game.html',
#   'providerPublishTime': 1709829014,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/OuiODrMPV4ODme56z_AEBA--~B/aD0xMTQ0O3c9MTcxNjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2022-01/e44f8410-7925-11ec-bcf6-da9b33ed53cc',
#      'width': 1716,
#      'height': 1144,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/MkxTihemkADEuhp3wBFCfw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2022-01/e44f8410-7925-11ec-bcf6-da9b33ed53cc',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '2aa3f9d6-fa40-3b41-b1f2-38c67e0bf5dd',
#   'title': 'Orthopedic Implants Market Set for a Remarkable Surge, Global Revenue to Reach US$52.45 Billion by 2030',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/orthopedic-implants-market-set-remarkable-162700976.html',
#   'providerPublishTime': 1709828820,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/pjCHBNf5qAUHZQHyMBndYw--~B/aD0yMzQ7dz0yOTY7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/globenewswire.com/3de38acb7686e5ffa6ede793d4f703bf',
#      'width': 296,
#      'height': 234,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/XfoUTPtNP4RjsdTpbqVjXA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/3de38acb7686e5ffa6ede793d4f703bf',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '6c80a6b5-79cd-30fb-b349-85091c8383c5',
#   'title': 'Global Bakery Premixes Market Report 2023-2028: Analysis Across Complete Mix, Dough-Base Mix, and Dough Concentrates with Puratos, ADM, Cargill, Nestle, DSM, and Oy Karl Fazer Dominating',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/global-bakery-premixes-market-report-162700991.html',
#   'providerPublishTime': 1709828820,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/q1ScF27are1XxewxR4FRXQ--~B/aD00MDA7dz02MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/globenewswire.com/a1f2fdc20cb1c52308e58f6c17ef1857',
#      'width': 600,
#      'height': 400,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/FaCwXwp.oQ3rWo1laAh2vA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/a1f2fdc20cb1c52308e58f6c17ef1857',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': 'fc5cce4a-4a01-3fce-a263-516e32f113c7',
#   'title': 'Adult Diaper Market Size to Garner US$28.2 Bn\xa0in\xa02030, Projects a New Report of Fairfield Market Research',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/adult-diaper-market-size-garner-162700475.html',
#   'providerPublishTime': 1709828820,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/pjCHBNf5qAUHZQHyMBndYw--~B/aD0yMzQ7dz0yOTY7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/globenewswire.com/3de38acb7686e5ffa6ede793d4f703bf',
#      'width': 296,
#      'height': 234,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/XfoUTPtNP4RjsdTpbqVjXA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/3de38acb7686e5ffa6ede793d4f703bf',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '27c20918-26ba-32e9-9bc5-aef46323f087',
#   'title': 'IBD 50 Stock First Citizens Bank Still Ripe For The Picking',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/27c20918-26ba-32e9-9bc5-aef46323f087/ibd-50-stock-first-citizens.html',
#   'providerPublishTime': 1709828815,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/wl5C8IqCSFLpIX_moQ7eyw--~B/aD01NjM7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/4313116d9bbbe4d153bc1648ccebdbc9',
#      'width': 1000,
#      'height': 563,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/2pv1KAkbMCIi1DUfylPeOw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/4313116d9bbbe4d153bc1648ccebdbc9',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['FCNCA']},
#  {'uuid': '68fe5495-38d5-3676-ada9-d836434e306e',
#   'title': 'FRN Variable Rate Fix',
#   'publisher': 'Business Wire',
#   'link': 'https://finance.yahoo.com/news/frn-variable-rate-fix-162600071.html',
#   'providerPublishTime': 1709828760,
#   'type': 'STORY'},
#  {'uuid': '4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b',
#   'title': 'Magnificent Seven Stocks To Buy And Watch: Meta, Nvidia Rally To Record Highs',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks-to.html',
#   'providerPublishTime': 1709828742,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/IVY_jviTG_ue49k31izfew--~B/aD02MDA7dz0xMDY1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 1065,
#      'height': 600,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/EDUpiEmpjj.CUhr9H67TBQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'AAPL', 'TSLA', 'META', 'MSFT']},
#  {'uuid': '32284e7d-18eb-3b53-92eb-5ef441e10cf7',
#   'title': 'China just pulled the country version of a company canceling its quarterly earnings call',
#   'publisher': 'Business Insider',
#   'link': 'https://finance.yahoo.com/m/32284e7d-18eb-3b53-92eb-5ef441e10cf7/china-just-pulled-the-country.html',
#   'providerPublishTime': 1709828713,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/km5k5Q2JpfEkdy__vtej6w--~B/aD0xODA4O3c9MjQxMTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/business_insider_articles_888/25ac4ccec80294467662bbb248fc25cb',
#      'width': 2411,
#      'height': 1808,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/tSGvgXnKPsbIxfjpaJCSuw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business_insider_articles_888/25ac4ccec80294467662bbb248fc25cb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}}]
